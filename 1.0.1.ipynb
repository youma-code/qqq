# %% [markdown]
# <a href="https://colab.research.google.com/github/youma-code/qqq/blob/main/1.0.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import time


# ======================
# データ取得
# ======================
ticker = "AAPL"
start_date = "2020-01-01"
end_date = pd.to_datetime("today").strftime("%Y-%m-%d")

def download_data(ticker, start, end):
    for _ in range(5):
        df = yf.download(ticker, start=start, end=end)
        if not df.empty:
            return df
        time.sleep(3)
    return pd.DataFrame()

df = download_data(ticker, start_date, end_date)

# Handle potential MultiIndex from yfinance to ensure df['Close'] is a Series
if isinstance(df.columns, pd.MultiIndex):
    df = df[['Close', 'High', 'Low', 'Volume']].droplevel(level=1, axis=1)
else:
    df = df[['Close', 'High', 'Low', 'Volume']].copy() # Use .copy() to avoid SettingWithCopyWarning
df.columns = ['Close', 'High', 'Low', 'Volume'] # Ensure column names are simple strings
df.dropna(inplace=True)

# ======================
# 特徴量作成
# ======================

# SMA
df['SMA_5'] = df['Close'].rolling(5).mean()
df['SMA_25'] = df['Close'].rolling(25).mean()
df['SMA_DIFF'] = df['SMA_5'] - df['SMA_25']
df['SMA_RATIO'] = df['SMA_5'] / df['SMA_25']

# Target
future_max = df['Close'].shift(-1).rolling(3).max()
df['Target'] = ((future_max / df['Close'] - 1) > 0.0075).astype(int)

# RSI
delta = df['Close'].diff()
gain = delta.clip(lower=0).rolling(14).mean()
loss = (-delta.clip(upper=0)).rolling(14).mean()
rs = gain / loss
df['RSI'] = 100 - (100 / (1 + rs))

# MACD
ema12 = df['Close'].ewm(span=12).mean()
ema26 = df['Close'].ewm(span=26).mean()
df['MACD'] = ema12 - ema26
df['Signal_Line'] = df['MACD'].ewm(span=9).mean()
df['MACD_Hist'] = df['MACD'] - df['Signal_Line']

df['Daily_Return'] = df['Close'].pct_change()
df['Volatility_Short'] = df['Daily_Return'].rolling(5).std()


# ATR
tr = pd.concat([
    df['High'] - df['Low'],
    abs(df['High'] - df['Close'].shift()),
    abs(df['Low'] - df['Close'].shift())
], axis=1).max(axis=1)

df['ATR'] = tr.rolling(14).mean()

# ======================
# ADX（トレンド強さ）
# ======================

window = 14

high = df['High']
low = df['Low']
close = df['Close']

plus_dm = high.diff()
minus_dm = -low.diff()

plus_dm[plus_dm < 0] = 0
minus_dm[minus_dm < 0] = 0

tr = pd.concat([
    high - low,
    (high - close.shift()).abs(),
    (low - close.shift()).abs()
], axis=1).max(axis=1)

atr = tr.rolling(window).mean()

plus_di = 100 * (plus_dm.rolling(window).mean() / atr)
minus_di = 100 * (minus_dm.rolling(window).mean() / atr)

dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100

df['ADX'] = dx.rolling(window).mean()

# ボリンジャー
# Ensure ma and std are Series by using .squeeze() if they result in single-column DataFrames
ma = df['Close'].rolling(20).mean().squeeze()
std = df['Close'].rolling(20).std().squeeze()

df['Upper_BB'] = ma + 2 * std
df['Lower_BB'] = ma - 2 * std
df['BB_Width'] = (df['Upper_BB'] - df['Lower_BB']) / ma

# ラグ
for lag in range(1, 6):
    df[f'Close_Lag_{lag}'] = df['Close'].shift(lag)

# 最後にNaN削除
df.dropna(inplace=True)

print("セル1完了:", df.shape)
# Out:
# /tmp/ipykernel_18148/3527103283.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# セル1完了: (1559, 25)

# %%
# ======================
# 特徴量リスト（固定）
# ======================

features = [
    'SMA_5', 'SMA_25', 'SMA_DIFF', 'SMA_RATIO',
    'RSI', 'MACD', 'Signal_Line', 'MACD_Hist',
    'ATR',
    'Upper_BB', 'Lower_BB', 'BB_Width',
    'Volatility_Short',
    'ADX'  # ←これ追加
]
# ラグ特徴量（セル1で作ったやつに対応）
for lag in range(1, 6):
    features.append(f'Close_Lag_{lag}')

# 存在しない列があったら弾く（安全対策）
features = [f for f in features if f in df.columns]

print("使用特徴量数:", len(features))
print(features[:10])
# Out:
# 使用特徴量数: 19
# ['SMA_5', 'SMA_25', 'SMA_DIFF', 'SMA_RATIO', 'RSI', 'MACD', 'Signal_Line', 'MACD_Hist', 'ATR', 'Upper_BB']

# %%
# ======================
# X, y 作成
# ======================

# 念のためチェック
assert 'Target' in df.columns, "Target列が存在しません"

# Xとy
X = df[features].copy()
y = df['Target'].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Target分布:")
print(y.value_counts(normalize=True))
# Out:
# X shape: (1559, 19)
# y shape: (1559,)
# Target分布:
# Target
# 0    0.516357
# 1    0.483643
# Name: proportion, dtype: float64

# %%
X = df[features]
y = df['Target']
print(f"X and y defined. Feature matrix shape: {X.shape}")
# Out:
# X and y defined. Feature matrix shape: (1559, 19)

# %%
# ======================
# 時系列分割
# ======================

split_index = int(len(df) * 0.8)

X_train = X.iloc[:split_index].copy()
X_test  = X.iloc[split_index:].copy()

y_train = y.iloc[:split_index].copy()
y_test  = y.iloc[split_index:].copy()

print("Train期間:", X_train.index.min(), "→", X_train.index.max())
print("Test期間 :", X_test.index.min(), "→", X_test.index.max())

print("Train size:", X_train.shape)
print("Test size :", X_test.shape)
# Out:
# Train期間: 2020-02-11 00:00:00 → 2025-01-27 00:00:00
# Test期間 : 2025-01-28 00:00:00 → 2026-04-24 00:00:00
# Train size: (1247, 19)
# Test size : (312, 19)

# %%
# ======================
# SMOTE（訓練データのみ）
# ======================

from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", y_train.value_counts())
print("After SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Before SMOTE: Target
# 1    632
# 0    615
# Name: count, dtype: int64
# After SMOTE:
# Target
# 1    632
# 0    632
# Name: count, dtype: int64

# %%
# ======================
# RandomForest チューニング
# ======================

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# モデル定義
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# パラメータ範囲
param_dist_rf = {
    'n_estimators': randint(100, 500),
    'max_depth': randint(3, 20),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 5),
    'max_features': ['sqrt', 'log2', None]
}

# チューニング
random_search_rf = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist_rf,
    n_iter=30,                # 最初は軽めでOK（後で増やせる）
    scoring='f1',             # 不均衡データ向け
    cv=3,                     # 時系列じゃない簡易CV（後で改善）
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# 学習（SMOTE後データ使う）
random_search_rf.fit(X_train_resampled, y_train_resampled)

# 最適モデル
model_rf_tuned = random_search_rf.best_estimator_

print("Best params:", random_search_rf.best_params_)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best params: {'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 335}

# %%
# ======================
# XGBoost チューニング
# ======================

from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# モデル定義
xgb = XGBClassifier(
    random_state=42,
    eval_metric='logloss',
    n_jobs=-1
)

# パラメータ範囲
param_dist_xgb = {
    'n_estimators': randint(100, 500),
    'max_depth': randint(3, 12),
    'learning_rate': uniform(0.01, 0.2),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 0.5),
    'reg_lambda': uniform(0.5, 1.5)
}

# チューニング
random_search_xgb = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist_xgb,
    n_iter=30,          # 最初は軽め
    scoring='f1',
    cv=3,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# 学習（SMOTE後データ）
random_search_xgb.fit(X_train_resampled, y_train_resampled)

# 最適モデル
model_xgb_tuned = random_search_xgb.best_estimator_

print("Best params:", random_search_xgb.best_params_)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best params: {'colsample_bytree': np.float64(0.8650089137415928), 'gamma': np.float64(0.15585553804470548), 'learning_rate': np.float64(0.11401360423556216), 'max_depth': 6, 'n_estimators': 409, 'reg_alpha': np.float64(0.01565664622777929), 'reg_lambda': np.float64(1.7634271618924977), 'subsample': np.float64(0.7799016533479063)}

# %%
# ======================
# 予測確率の取得
# ======================

# RandomForest
proba_class1_rf = model_rf_tuned.predict_proba(X_test)[:, 1]

# XGBoost
proba_class1_xgb = model_xgb_tuned.predict_proba(X_test)[:, 1]

# 確認
print("RF proba shape:", proba_class1_rf.shape)
print("XGB proba shape:", proba_class1_xgb.shape)
# Out:
# RF proba shape: (312,)
# XGB proba shape: (312,)

# %%
# ======================
# 戦略A・Bの定義
# ======================

# 閾値（あとで調整可能）
threshold = 0.6

# --- 戦略A：AND条件（両モデルが強気） ---
strategy_A = (
    (proba_class1_rf > threshold) &
    (proba_class1_xgb > threshold)
).astype(int)

# --- 戦略B：XGBoost重視 ---
strategy_B = (
    (proba_class1_xgb > threshold)
).astype(int)

# 確認
print("Strategy A trades:", strategy_A.sum())
print("Strategy B trades:", strategy_B.sum())
# Out:
# Strategy A trades: 19
# Strategy B trades: 90

# %%
# ======================
# バックテスト関数（統一版）
# ======================

def run_backtest(df, X_test, signals, initial_balance=100000, risk_per_trade=0.02):

    # --- テスト期間のデータだけ使う ---
    df_bt = df.loc[X_test.index].copy()

    # --- 必須列チェック ---
    required_cols = ['Close', 'ATR']
    df_bt = df_bt.dropna(subset=required_cols)

    # signalsも同じindexに揃える
    signals = signals.loc[df_bt.index]

    # --- 初期化 ---
    balance = initial_balance
    equity_curve = []
    position = 0
    entry_price = 0
    trade_count = 0
    win_count = 0

    for i in range(len(df_bt) - 1):
        row = df_bt.iloc[i]
        next_row = df_bt.iloc[i + 1]

        signal = signals.iloc[i]

        # ======================
        # エントリー
        # ======================
        if position == 0 and signal == 1:

            # ATR-based position sizing
            atr = row['ATR']
            if pd.isna(atr) or atr == 0:
                continue

            risk_amount = balance * risk_per_trade
            stop_loss_distance = atr * 2

            position_size = risk_amount / stop_loss_distance

            entry_price = next_row['Close']
            position = position_size
            trade_count += 1

        # ======================
        # ポジション保有中
        # ======================
        elif position > 0:

            current_price = next_row['Close']

            # ストップロス
            stop_price = entry_price - (row['ATR'] * 2)

            # 利確（リスクリワード 1:2）
            take_profit_price = entry_price + (row['ATR'] * 4)

            exit_flag = False

            if current_price <= stop_price:
                exit_flag = True
            elif current_price >= take_profit_price:
                exit_flag = True

            if exit_flag:
                pnl = (current_price - entry_price) * position
                balance += pnl

                if pnl > 0:
                    win_count += 1

                position = 0

        equity_curve.append(balance)

    # --- 最後のポジション強制決済 ---
    if position > 0:
        final_price = df_bt.iloc[-1]['Close']
        pnl = (final_price - entry_price) * position
        balance += pnl

        if pnl > 0:
            win_count += 1

    # --- 結果まとめ ---
    win_rate = (win_count / trade_count * 100) if trade_count > 0 else 0
    total_return = (balance / initial_balance - 1) * 100

    results = {
        'Final Balance': balance,
        'Total Return (%)': total_return,
        'Total Trades': trade_count,
        'Win Rate (%)': win_rate
    }

    return results, equity_curve

# %%
# ======================
# バックテスト実行
# ======================

import pandas as pd

# signalsをSeriesに変換（超重要）
signals_A = pd.Series(strategy_A, index=X_test.index)
signals_B = pd.Series(strategy_B, index=X_test.index)

# --- 戦略A ---
results_A, equity_A = run_backtest(df, X_test, signals_A)

# --- 戦略B ---
results_B, equity_B = run_backtest(df, X_test, signals_B)

# 結果表示
print("===== Strategy A =====")
for k, v in results_A.items():
    print(f"{k}: {v}")

print("\n===== Strategy B =====")
for k, v in results_B.items():
    print(f"{k}: {v}")
# Out:
# ===== Strategy A =====
# Final Balance: 110207.68283131806
# Total Return (%): 10.207682831318055
# Total Trades: 4
# Win Rate (%): 75.0
#
# ===== Strategy B =====
# Final Balance: 108444.62982884809
# Total Return (%): 8.444629828848083
# Total Trades: 11
# Win Rate (%): 45.45454545454545

# %%
import matplotlib.pyplot as plt

plt.plot(equity_A, label="Strategy A")
plt.plot(equity_B, label="Strategy B")

plt.legend()
plt.title("Equity Curve")
plt.show()

# %%
# ======================
# Optunaのインストール
# ======================
# !pip install optuna

import optuna
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE


# ======================
# 評価指標
# ======================
def calc_metrics(equity):
    equity = np.array(equity)

    returns = np.diff(equity)
    gains = returns[returns > 0].sum()
    losses = -returns[returns < 0].sum() + 1e-9

    profit_factor = gains / losses

    peak = np.maximum.accumulate(equity)
    dd = (equity - peak) / peak
    max_dd = abs(dd.min())

    return profit_factor, max_dd


# ======================
# Optuna
# ======================
def objective(trial):

    model_params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 400),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 0.5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 0.5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.5, 2.0),
    }

    threshold = trial.suggest_float("threshold", 0.45, 0.7)
    adx_th = trial.suggest_int("adx_th", 10, 25)
    vol_q = trial.suggest_float("vol_q", 0.5, 0.9)

    tscv = TimeSeriesSplit(n_splits=3)

    scores = []

    for train_idx, val_idx in tscv.split(X):

        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train = y.iloc[train_idx]

        smote = SMOTE(random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

        model = XGBClassifier(**model_params, random_state=42, eval_metric='logloss')
        model.fit(X_train_res, y_train_res)

        proba = model.predict_proba(X_val)[:, 1]

        df_slice = df.loc[X_val.index].copy()
        df_slice["proba"] = proba

        vol_threshold = df_slice["Volatility_Short"].quantile(vol_q)

        signals = (
            (df_slice["proba"] > threshold) &
            (df_slice["ADX"] > adx_th) &
            (df_slice["Volatility_Short"] > vol_threshold)
        ).astype(int)

        results, equity = run_backtest(df, X_val, signals)

        # ======================
        # metrics
        # ======================
        trades = results["Total Trades"]
        winrate = results["Win Rate (%)"] / 100

        equity = np.array(equity)
        returns = np.diff(equity) / equity[:-1]

        # PF（簡易）
        gross_profit = np.sum(returns[returns > 0])
        gross_loss = -np.sum(returns[returns < 0]) + 1e-9
        pf = gross_profit / gross_loss

        dd = np.min(equity / np.maximum.accumulate(equity) - 1)

        # ======================
        # スコア（重要）
        # ======================
        score = (
            winrate * 0.4 +
            np.log1p(pf) * 0.3 +
            (1 + dd) * 0.3   # DDはマイナスなので補正
        )

        scores.append(score)

    return np.mean(scores)


# ======================
# 実行
# ======================
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print(study.best_params)
# Out:
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 8.3 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0
# [I 2026-04-25 04:46:46,837] A new study created in memory with name: no-name-ff8e01c6-d418-48ab-aadd-9896ff72e57b
# [I 2026-04-25 04:46:47,869] Trial 0 finished with value: 0.5303742737841292 and parameters: {'n_estimators': 134, 'max_depth': 6, 'learning_rate': 0.19069906153746166, 'subsample': 0.6794467282005223, 'colsample_bytree': 0.6577473526389592, 'gamma': 0.3114866350798173, 'reg_alpha': 0.38222080809565834, 'reg_lambda': 1.328975503751017, 'threshold': 0.6416497429507605, 'adx_th': 22, 'vol_q': 0.7981191059621553}. Best is trial 0 with value: 0.5303742737841292.
# [I 2026-04-25 04:46:48,833] Trial 1 finished with value: 0.6466080806172635 and parameters: {'n_estimators': 139, 'max_depth': 5, 'learning_rate': 0.18581327011675958, 'subsample': 0.9541081014678342, 'colsample_bytree': 0.9728076795187928, 'gamma': 0.3438425833944928, 'reg_alpha': 0.48078627870197016, 'reg_lambda': 1.608133606362676, 'threshold': 0.49246238307423157, 'adx_th': 16, 'vol_q': 0.8996651221317815}. Best is trial 1 with value: 0.6466080806172635.
# [I 2026-04-25 04:46:54,081] Trial 2 finished with value: 0.7455726667676273 and parameters: {'n_estimators': 395, 'max_depth': 5, 'learning_rate': 0.024671175882325938, 'subsample': 0.9787231508884514, 'colsample_bytree': 0.8964410549261419, 'gamma': 0.02797199436326947, 'reg_alpha': 0.03015816995181636, 'reg_lambda': 0.8848384581434989, 'threshold': 0.5592988861604151, 'adx_th': 19, 'vol_q': 0.7841952114150013}. Best is trial 2 with value: 0.7455726667676273.
# [I 2026-04-25 04:46:58,204] Trial 3 finished with value: 0.5946084736176109 and parameters: {'n_estimators': 384, 'max_depth': 6, 'learning_rate': 0.014410160539842716, 'subsample': 0.6769203299999765, 'colsample_bytree': 0.9883481187661116, 'gamma': 0.061229641406288005, 'reg_alpha': 0.28979224419739624, 'reg_lambda': 1.7924290061295125, 'threshold': 0.6238156632535025, 'adx_th': 16, 'vol_q': 0.6878896722655365}. Best is trial 2 with value: 0.7455726667676273.
# [I 2026-04-25 04:46:59,275] Trial 4 finished with value: 0.7418605800116165 and parameters: {'n_estimators': 182, 'max_depth': 4, 'learning_rate': 0.18303448034322173, 'subsample': 0.6738739812533603, 'colsample_bytree': 0.9794957412781418, 'gamma': 0.4342035820985828, 'reg_alpha': 0.19211626691968092, 'reg_lambda': 0.5983535941339596, 'threshold': 0.5961278579474665, 'adx_th': 16, 'vol_q': 0.7599519757455933}. Best is trial 2 with value: 0.7455726667676273.
# [I 2026-04-25 04:47:00,727] Trial 5 finished with value: 0.474540120533587 and parameters: {'n_estimators': 274, 'max_depth': 4, 'learning_rate': 0.05895022233828879, 'subsample': 0.8041905222451601, 'colsample_bytree': 0.8392230852979083, 'gamma': 0.1916840006120939, 'reg_alpha': 0.07866055961213136, 'reg_lambda': 1.2463383223875915, 'threshold': 0.690294303722606, 'adx_th': 11, 'vol_q': 0.8989223868856755}. Best is trial 2 with value: 0.7455726667676273.
# [I 2026-04-25 04:47:05,547] Trial 6 finished with value: 0.4821481961314333 and parameters: {'n_estimators': 344, 'max_depth': 9, 'learning_rate': 0.11146856009423184, 'subsample': 0.8269439620943203, 'colsample_bytree': 0.9554838232671677, 'gamma': 0.09522226340469014, 'reg_alpha': 0.11993133698744751, 'reg_lambda': 0.6490795106653336, 'threshold': 0.593562360074522, 'adx_th': 24, 'vol_q': 0.8734629789827622}. Best is trial 2 with value: 0.7455726667676273.
# [I 2026-04-25 04:47:10,721] Trial 7 finished with value: 0.713967337222925 and parameters: {'n_estimators': 330, 'max_depth': 8, 'learning_rate': 0.03417475306171823, 'subsample': 0.9196621703787498, 'colsample_bytree': 0.9909310225677965, 'gamma': 0.28947347984952476, 'reg_alpha': 0.07007020073967768, 'reg_lambda': 1.8923065604559035, 'threshold': 0.482434704016696, 'adx_th': 20, 'vol_q': 0.7638778521748624}. Best is trial 2 with value: 0.7455726667676273.
# [I 2026-04-25 04:47:12,588] Trial 8 finished with value: 0.8117949864257287 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.035631779051857056, 'subsample': 0.8504150423796017, 'colsample_bytree': 0.7227492166933182, 'gamma': 0.32206828860434306, 'reg_alpha': 0.15454253627637182, 'reg_lambda': 1.9129358393503655, 'threshold': 0.49636849980340647, 'adx_th': 22, 'vol_q': 0.5641098240564878}. Best is trial 8 with value: 0.8117949864257287.
# [I 2026-04-25 04:47:13,957] Trial 9 finished with value: 0.7497240708455859 and parameters: {'n_estimators': 395, 'max_depth': 7, 'learning_rate': 0.17642013909786872, 'subsample': 0.9252575376561585, 'colsample_bytree': 0.7175194218363863, 'gamma': 0.34175455976990393, 'reg_alpha': 0.22951194846526485, 'reg_lambda': 1.7080718172791869, 'threshold': 0.6020612336838618, 'adx_th': 25, 'vol_q': 0.6869246692207398}. Best is trial 8 with value: 0.8117949864257287.
# [I 2026-04-25 04:47:14,899] Trial 10 finished with value: 0.7692019799398938 and parameters: {'n_estimators': 241, 'max_depth': 3, 'learning_rate': 0.08243678527179932, 'subsample': 0.8657296310143121, 'colsample_bytree': 0.754303989775866, 'gamma': 0.46733336571701767, 'reg_alpha': 0.3196716231265764, 'reg_lambda': 1.3939435701059233, 'threshold': 0.5264260875792602, 'adx_th': 12, 'vol_q': 0.5288182221517641}. Best is trial 8 with value: 0.8117949864257287.
# [I 2026-04-25 04:47:15,796] Trial 11 finished with value: 0.7454118022291417 and parameters: {'n_estimators': 226, 'max_depth': 3, 'learning_rate': 0.08502236679030879, 'subsample': 0.8592874520945509, 'colsample_bytree': 0.7538174764247634, 'gamma': 0.4660785218962028, 'reg_alpha': 0.3130237309988595, 'reg_lambda': 1.384812513605818, 'threshold': 0.5311586931580446, 'adx_th': 10, 'vol_q': 0.5282540890706787}. Best is trial 8 with value: 0.8117949864257287.
# [I 2026-04-25 04:47:16,752] Trial 12 finished with value: 0.7084731166055805 and parameters: {'n_estimators': 258, 'max_depth': 3, 'learning_rate': 0.1160003290104758, 'subsample': 0.765654137242904, 'colsample_bytree': 0.6154097508509531, 'gamma': 0.4109965740539756, 'reg_alpha': 0.14869343981263541, 'reg_lambda': 1.9920868062405073, 'threshold': 0.4570849112365777, 'adx_th': 12, 'vol_q': 0.5159773466619282}. Best is trial 8 with value: 0.8117949864257287.
# [I 2026-04-25 04:47:20,197] Trial 13 finished with value: 0.7034781933312683 and parameters: {'n_estimators': 308, 'max_depth': 3, 'learning_rate': 0.06913285499250457, 'subsample': 0.8806387598219729, 'colsample_bytree': 0.7867008031608171, 'gamma': 0.2281963526723242, 'reg_alpha': 0.3936631073990865, 'reg_lambda': 1.0288619280079554, 'threshold': 0.5302442045833322, 'adx_th': 13, 'vol_q': 0.5897999809184008}. Best is trial 8 with value: 0.8117949864257287.
# [I 2026-04-25 04:47:21,585] Trial 14 finished with value: 0.8312622454705828 and parameters: {'n_estimators': 208, 'max_depth': 10, 'learning_rate': 0.14915041328467415, 'subsample': 0.737729180187116, 'colsample_bytree': 0.7003422735551607, 'gamma': 0.49415600003097043, 'reg_alpha': 0.34583639661630644, 'reg_lambda': 1.5376318053113966, 'threshold': 0.5140893229226075, 'adx_th': 22, 'vol_q': 0.60217004824292}. Best is trial 14 with value: 0.8312622454705828.
# [I 2026-04-25 04:47:23,529] Trial 15 finished with value: 0.7632093777183847 and parameters: {'n_estimators': 196, 'max_depth': 10, 'learning_rate': 0.1475819099836748, 'subsample': 0.7426426254234074, 'colsample_bytree': 0.6845464199014469, 'gamma': 0.15539349228581834, 'reg_alpha': 0.21305711222795898, 'reg_lambda': 1.6002055953742003, 'threshold': 0.4961946543476869, 'adx_th': 22, 'vol_q': 0.6155491954851008}. Best is trial 14 with value: 0.8312622454705828.
# [I 2026-04-25 04:47:25,201] Trial 16 finished with value: 0.7800234888217846 and parameters: {'n_estimators': 178, 'max_depth': 10, 'learning_rate': 0.15105092432253234, 'subsample': 0.6129909377353142, 'colsample_bytree': 0.836005323829308, 'gamma': 0.39050595066020555, 'reg_alpha': 0.4093675810421662, 'reg_lambda': 1.5487115873066437, 'threshold': 0.4510123064307181, 'adx_th': 22, 'vol_q': 0.6112390485701162}. Best is trial 14 with value: 0.8312622454705828.
# [I 2026-04-25 04:47:27,291] Trial 17 finished with value: 0.7545886715361002 and parameters: {'n_estimators': 286, 'max_depth': 8, 'learning_rate': 0.13753502575937265, 'subsample': 0.7438915872916392, 'colsample_bytree': 0.6060599481806739, 'gamma': 0.2531146956846801, 'reg_alpha': 0.2688813228938346, 'reg_lambda': 1.99013452563299, 'threshold': 0.5497506875587601, 'adx_th': 19, 'vol_q': 0.5818754667991973}. Best is trial 14 with value: 0.8312622454705828.
# [I 2026-04-25 04:47:28,733] Trial 18 finished with value: 0.8579401340111049 and parameters: {'n_estimators': 107, 'max_depth': 7, 'learning_rate': 0.054413785870642176, 'subsample': 0.7972817787689253, 'colsample_bytree': 0.6834440016306061, 'gamma': 0.4919433344441938, 'reg_alpha': 0.49734765998506436, 'reg_lambda': 1.1205271800300376, 'threshold': 0.5098607556353054, 'adx_th': 23, 'vol_q': 0.6564632603417851}. Best is trial 18 with value: 0.8579401340111049.
# [I 2026-04-25 04:47:30,254] Trial 19 finished with value: 0.8695497832193707 and parameters: {'n_estimators': 119, 'max_depth': 9, 'learning_rate': 0.1280957849898249, 'subsample': 0.7714577971301931, 'colsample_bytree': 0.6573004346607871, 'gamma': 0.4968223441219219, 'reg_alpha': 0.48887027824749907, 'reg_lambda': 1.1160907028193854, 'threshold': 0.5217019041319018, 'adx_th': 24, 'vol_q': 0.6558186241075754}. Best is trial 19 with value: 0.8695497832193707.
# [I 2026-04-25 04:47:33,363] Trial 20 finished with value: 0.9120936209144808 and parameters: {'n_estimators': 117, 'max_depth': 8, 'learning_rate': 0.1259850854178474, 'subsample': 0.7877520014197381, 'colsample_bytree': 0.649665565405747, 'gamma': 0.3820222785829188, 'reg_alpha': 0.47729765870992935, 'reg_lambda': 1.0536389351328561, 'threshold': 0.5641564101103687, 'adx_th': 25, 'vol_q': 0.6523847682370586}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:34,417] Trial 21 finished with value: 0.8313601971241434 and parameters: {'n_estimators': 102, 'max_depth': 8, 'learning_rate': 0.12541395624572035, 'subsample': 0.7799856196917418, 'colsample_bytree': 0.6491250594012102, 'gamma': 0.4985394004647673, 'reg_alpha': 0.49861046733526254, 'reg_lambda': 1.0946758291102197, 'threshold': 0.567031904490661, 'adx_th': 25, 'vol_q': 0.6519855068768868}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:35,724] Trial 22 finished with value: 0.7409491793539341 and parameters: {'n_estimators': 107, 'max_depth': 9, 'learning_rate': 0.08978847598907858, 'subsample': 0.8088540520917652, 'colsample_bytree': 0.659528911507211, 'gamma': 0.3838782390667414, 'reg_alpha': 0.44819705118855, 'reg_lambda': 0.8337389929542665, 'threshold': 0.5463934697260183, 'adx_th': 24, 'vol_q': 0.7288194973455122}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:37,069] Trial 23 finished with value: 0.8292736137141592 and parameters: {'n_estimators': 148, 'max_depth': 7, 'learning_rate': 0.0977920547986239, 'subsample': 0.7073213294999074, 'colsample_bytree': 0.6337765411293855, 'gamma': 0.44174489053668664, 'reg_alpha': 0.43791350135718377, 'reg_lambda': 1.155816519452406, 'threshold': 0.5774972462442329, 'adx_th': 24, 'vol_q': 0.6520176077072837}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:38,372] Trial 24 finished with value: 0.7507636977013062 and parameters: {'n_estimators': 161, 'max_depth': 9, 'learning_rate': 0.16765832451790832, 'subsample': 0.7914776776069046, 'colsample_bytree': 0.6868039880909547, 'gamma': 0.3758521023749977, 'reg_alpha': 0.4575857354911773, 'reg_lambda': 0.955223161966062, 'threshold': 0.4747696642984518, 'adx_th': 20, 'vol_q': 0.6468513836987524}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:39,831] Trial 25 finished with value: 0.7456540424678609 and parameters: {'n_estimators': 119, 'max_depth': 7, 'learning_rate': 0.05625051011943734, 'subsample': 0.8239445102084825, 'colsample_bytree': 0.7498582785279699, 'gamma': 0.44382116043152886, 'reg_alpha': 0.4996381609448465, 'reg_lambda': 0.7714919499736792, 'threshold': 0.5116152459820578, 'adx_th': 23, 'vol_q': 0.7128567968123305}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:41,069] Trial 26 finished with value: 0.8397194162396792 and parameters: {'n_estimators': 126, 'max_depth': 8, 'learning_rate': 0.12393345934305097, 'subsample': 0.7157109059630238, 'colsample_bytree': 0.6023566602104272, 'gamma': 0.41435357661930383, 'reg_alpha': 0.4176410047392815, 'reg_lambda': 1.210121916957152, 'threshold': 0.5434863549693438, 'adx_th': 25, 'vol_q': 0.6718141872019928}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:42,538] Trial 27 finished with value: 0.8732972014198207 and parameters: {'n_estimators': 163, 'max_depth': 9, 'learning_rate': 0.10331329862899322, 'subsample': 0.633546281566219, 'colsample_bytree': 0.6712084062260497, 'gamma': 0.4964221093791072, 'reg_alpha': 0.36870717530079766, 'reg_lambda': 1.049283178034355, 'threshold': 0.5766356731886654, 'adx_th': 20, 'vol_q': 0.6311862883629643}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:46,448] Trial 28 finished with value: 0.7352739016947226 and parameters: {'n_estimators': 161, 'max_depth': 9, 'learning_rate': 0.10076388169511108, 'subsample': 0.6099826790201361, 'colsample_bytree': 0.64023680165796, 'gamma': 0.36726890672203144, 'reg_alpha': 0.36572358043440695, 'reg_lambda': 0.726429733661405, 'threshold': 0.6242527171590178, 'adx_th': 18, 'vol_q': 0.555241656885854}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:47,854] Trial 29 finished with value: 0.7205127717000449 and parameters: {'n_estimators': 142, 'max_depth': 9, 'learning_rate': 0.1334167650163442, 'subsample': 0.6468116928243202, 'colsample_bytree': 0.661632668799829, 'gamma': 0.271440472242015, 'reg_alpha': 0.3663379796254317, 'reg_lambda': 0.9652444309657896, 'threshold': 0.5821622620560735, 'adx_th': 21, 'vol_q': 0.7273758522013252}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:49,254] Trial 30 finished with value: 0.7774774004474528 and parameters: {'n_estimators': 164, 'max_depth': 8, 'learning_rate': 0.1621636040938713, 'subsample': 0.6509080792058627, 'colsample_bytree': 0.797791826400345, 'gamma': 0.46076024929229287, 'reg_alpha': 0.4633946043794195, 'reg_lambda': 1.3083357784418135, 'threshold': 0.6645472941403343, 'adx_th': 14, 'vol_q': 0.6246143667651088}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:50,247] Trial 31 finished with value: 0.8354450444991871 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.07238223168560179, 'subsample': 0.7719792124400372, 'colsample_bytree': 0.6743976107234645, 'gamma': 0.4907760495193353, 'reg_alpha': 0.4252972364225386, 'reg_lambda': 1.1332298808286112, 'threshold': 0.5180632731208514, 'adx_th': 23, 'vol_q': 0.6368118586907254}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:51,502] Trial 32 finished with value: 0.7763662009201946 and parameters: {'n_estimators': 125, 'max_depth': 7, 'learning_rate': 0.11551264473390858, 'subsample': 0.7016381938390883, 'colsample_bytree': 0.7165506452608873, 'gamma': 0.4216521688697078, 'reg_alpha': 0.4752872221383339, 'reg_lambda': 1.0298362835366806, 'threshold': 0.5600579424176818, 'adx_th': 23, 'vol_q': 0.6704972342339888}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:52,632] Trial 33 finished with value: 0.6946966312508893 and parameters: {'n_estimators': 135, 'max_depth': 8, 'learning_rate': 0.10454414125410982, 'subsample': 0.8887923889961507, 'colsample_bytree': 0.629330983474648, 'gamma': 0.4701708178479528, 'reg_alpha': 0.39398097308070246, 'reg_lambda': 0.9047248067044279, 'threshold': 0.5399592542467108, 'adx_th': 21, 'vol_q': 0.708645709872509}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:53,617] Trial 34 finished with value: 0.7983475362686816 and parameters: {'n_estimators': 122, 'max_depth': 6, 'learning_rate': 0.13932364560721525, 'subsample': 0.833210533800523, 'colsample_bytree': 0.701792851247112, 'gamma': 0.49305460229077447, 'reg_alpha': 0.47527494774487916, 'reg_lambda': 1.0465090328837314, 'threshold': 0.5706716868799945, 'adx_th': 24, 'vol_q': 0.6659355018413279}. Best is trial 20 with value: 0.9120936209144808.
# [I 2026-04-25 04:47:55,592] Trial 35 finished with value: 0.9193775188695789 and parameters: {'n_estimators': 153, 'max_depth': 9, 'learning_rate': 0.0473550866976439, 'subsample': 0.7584954689567763, 'colsample_bytree': 0.6633501904068919, 'gamma': 0.3435970823351416, 'reg_alpha': 0.4956895995148789, 'reg_lambda': 1.3362915281857404, 'threshold': 0.6194187532357736, 'adx_th': 17, 'vol_q': 0.629909898599661}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:47:58,416] Trial 36 finished with value: 0.7054868692508633 and parameters: {'n_estimators': 181, 'max_depth': 10, 'learning_rate': 0.19371542296491434, 'subsample': 0.9901914050895475, 'colsample_bytree': 0.7394389382293194, 'gamma': 0.30892556494672413, 'reg_alpha': 0.43545328268776107, 'reg_lambda': 1.4621674357156371, 'threshold': 0.613957978794674, 'adx_th': 17, 'vol_q': 0.821154916148288}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:02,115] Trial 37 finished with value: 0.7929912578302812 and parameters: {'n_estimators': 202, 'max_depth': 9, 'learning_rate': 0.04083469218876117, 'subsample': 0.7588450151284856, 'colsample_bytree': 0.909519048706401, 'gamma': 0.3351948152706153, 'reg_alpha': 0.33914072586747335, 'reg_lambda': 1.2835164778075554, 'threshold': 0.6680383150835157, 'adx_th': 15, 'vol_q': 0.565326920639303}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:04,526] Trial 38 finished with value: 0.3559839603295183 and parameters: {'n_estimators': 151, 'max_depth': 9, 'learning_rate': 0.010376635721158767, 'subsample': 0.6520536836543218, 'colsample_bytree': 0.7776004847257042, 'gamma': 0.35808621753238135, 'reg_alpha': 0.45771967814258974, 'reg_lambda': 1.2052250541257743, 'threshold': 0.6332576338076158, 'adx_th': 18, 'vol_q': 0.6889909165117994}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:05,913] Trial 39 finished with value: 0.825330407000688 and parameters: {'n_estimators': 219, 'max_depth': 10, 'learning_rate': 0.1585660082864695, 'subsample': 0.6306289870884721, 'colsample_bytree': 0.6636443578259217, 'gamma': 0.39655293856197527, 'reg_alpha': 0.010291942295904438, 'reg_lambda': 0.5152214044303826, 'threshold': 0.6455734115198991, 'adx_th': 17, 'vol_q': 0.626010356064876}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:08,226] Trial 40 finished with value: 0.6529738615682471 and parameters: {'n_estimators': 176, 'max_depth': 9, 'learning_rate': 0.025329199493848917, 'subsample': 0.6817760975215961, 'colsample_bytree': 0.6243965200589949, 'gamma': 0.21858157967580202, 'reg_alpha': 0.3795039891647829, 'reg_lambda': 1.3232287259918907, 'threshold': 0.5869331798104651, 'adx_th': 19, 'vol_q': 0.7372348697244876}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:11,728] Trial 41 finished with value: 0.7785426595906041 and parameters: {'n_estimators': 116, 'max_depth': 8, 'learning_rate': 0.05251638283459452, 'subsample': 0.8026170169475461, 'colsample_bytree': 0.6906020696838938, 'gamma': 0.4446372596814376, 'reg_alpha': 0.49791213838059123, 'reg_lambda': 1.1601490008165563, 'threshold': 0.6030868788593858, 'adx_th': 21, 'vol_q': 0.6383778764629247}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:13,740] Trial 42 finished with value: 0.7965360060765363 and parameters: {'n_estimators': 138, 'max_depth': 7, 'learning_rate': 0.04647475882523166, 'subsample': 0.7266605970643565, 'colsample_bytree': 0.6503743597409402, 'gamma': 0.0025296487144856883, 'reg_alpha': 0.48262386942502805, 'reg_lambda': 0.9589554602906593, 'threshold': 0.5057363847433425, 'adx_th': 25, 'vol_q': 0.6000577392043864}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:14,653] Trial 43 finished with value: 0.7236628659921595 and parameters: {'n_estimators': 112, 'max_depth': 5, 'learning_rate': 0.06515130097102881, 'subsample': 0.8378963185287435, 'colsample_bytree': 0.6748854551630223, 'gamma': 0.3047468681431314, 'reg_alpha': 0.4413360551548656, 'reg_lambda': 1.0671180423289925, 'threshold': 0.474089616407937, 'adx_th': 23, 'vol_q': 0.6906292095416428}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:18,645] Trial 44 finished with value: 0.8036081087337298 and parameters: {'n_estimators': 372, 'max_depth': 8, 'learning_rate': 0.023409194873650657, 'subsample': 0.7872143616133999, 'colsample_bytree': 0.7186890504373507, 'gamma': 0.4238338891495683, 'reg_alpha': 0.4065415202785314, 'reg_lambda': 1.385771581794872, 'threshold': 0.5562982115077462, 'adx_th': 20, 'vol_q': 0.6600105970764604}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:20,042] Trial 45 finished with value: 0.8976953798333279 and parameters: {'n_estimators': 153, 'max_depth': 9, 'learning_rate': 0.121587107352787, 'subsample': 0.8165666003095626, 'colsample_bytree': 0.8306344926578955, 'gamma': 0.46751024300890703, 'reg_alpha': 0.47810016165001407, 'reg_lambda': 0.8849138992077745, 'threshold': 0.6066852762489955, 'adx_th': 16, 'vol_q': 0.6750843601983036}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:21,701] Trial 46 finished with value: 0.7221784774982417 and parameters: {'n_estimators': 191, 'max_depth': 9, 'learning_rate': 0.1232957948965661, 'subsample': 0.6885444635955892, 'colsample_bytree': 0.8302175460472738, 'gamma': 0.45553476878332544, 'reg_alpha': 0.28757170885091765, 'reg_lambda': 0.8483489810656696, 'threshold': 0.6088053870910969, 'adx_th': 15, 'vol_q': 0.7490563699294477}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:25,736] Trial 47 finished with value: 0.7661564058937934 and parameters: {'n_estimators': 167, 'max_depth': 10, 'learning_rate': 0.11288733225406065, 'subsample': 0.8188120254058423, 'colsample_bytree': 0.8960868946082733, 'gamma': 0.40084270738665306, 'reg_alpha': 0.47223038458309957, 'reg_lambda': 0.6922124658100136, 'threshold': 0.5954157679312961, 'adx_th': 16, 'vol_q': 0.7798118195993466}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:27,030] Trial 48 finished with value: 0.7527655049303217 and parameters: {'n_estimators': 152, 'max_depth': 9, 'learning_rate': 0.09198279573543164, 'subsample': 0.95557275900564, 'colsample_bytree': 0.877078143101878, 'gamma': 0.4710120213255861, 'reg_alpha': 0.4188643114448143, 'reg_lambda': 0.807972177718531, 'threshold': 0.6178022919389186, 'adx_th': 15, 'vol_q': 0.7027885416772374}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:29,063] Trial 49 finished with value: 0.7980539138234723 and parameters: {'n_estimators': 135, 'max_depth': 10, 'learning_rate': 0.07869985245824322, 'subsample': 0.7519253636431247, 'colsample_bytree': 0.8613576511615723, 'gamma': 0.3522235984340742, 'reg_alpha': 0.4550048968562991, 'reg_lambda': 1.2372973493420314, 'threshold': 0.6369213857176957, 'adx_th': 16, 'vol_q': 0.6773908098491292}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:30,451] Trial 50 finished with value: 0.783028663923718 and parameters: {'n_estimators': 231, 'max_depth': 9, 'learning_rate': 0.1313515753706036, 'subsample': 0.8987129256929893, 'colsample_bytree': 0.851937617098185, 'gamma': 0.4317392023610561, 'reg_alpha': 0.387060271483263, 'reg_lambda': 0.8856232534282198, 'threshold': 0.589214450879975, 'adx_th': 17, 'vol_q': 0.5835721549067128}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:31,632] Trial 51 finished with value: 0.8096099359042098 and parameters: {'n_estimators': 112, 'max_depth': 8, 'learning_rate': 0.1449515238780365, 'subsample': 0.7720414781306493, 'colsample_bytree': 0.8186066866529379, 'gamma': 0.4804900713905696, 'reg_alpha': 0.48550381124579894, 'reg_lambda': 0.9957520173555484, 'threshold': 0.48748588869513926, 'adx_th': 19, 'vol_q': 0.6238560350592575}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:32,910] Trial 52 finished with value: 0.8942800984077666 and parameters: {'n_estimators': 129, 'max_depth': 8, 'learning_rate': 0.11039295867762572, 'subsample': 0.8531055056320156, 'colsample_bytree': 0.7039969540635809, 'gamma': 0.474965795290467, 'reg_alpha': 0.48220651903600364, 'reg_lambda': 1.1118304167426785, 'threshold': 0.5725651234399387, 'adx_th': 24, 'vol_q': 0.641818839540698}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:34,035] Trial 53 finished with value: 0.7410249914040382 and parameters: {'n_estimators': 149, 'max_depth': 8, 'learning_rate': 0.12370422455883229, 'subsample': 0.8529375090070462, 'colsample_bytree': 0.6440918850611886, 'gamma': 0.4568014001643321, 'reg_alpha': 0.43570109062725904, 'reg_lambda': 0.9228729468639016, 'threshold': 0.5767268924218021, 'adx_th': 24, 'vol_q': 0.6387581931040872}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:35,272] Trial 54 finished with value: 0.8107669472069774 and parameters: {'n_estimators': 127, 'max_depth': 9, 'learning_rate': 0.10688557606159763, 'subsample': 0.8752213418347092, 'colsample_bytree': 0.7033237087192256, 'gamma': 0.4779924847260381, 'reg_alpha': 0.4712052064390637, 'reg_lambda': 1.1909821332159463, 'threshold': 0.5643792001512772, 'adx_th': 14, 'vol_q': 0.611974235839534}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:39,706] Trial 55 finished with value: 0.8812671755151774 and parameters: {'n_estimators': 190, 'max_depth': 9, 'learning_rate': 0.09446690536954261, 'subsample': 0.8085510172247522, 'colsample_bytree': 0.619851137292321, 'gamma': 0.13793596823872312, 'reg_alpha': 0.4508433333102584, 'reg_lambda': 1.1070437532867414, 'threshold': 0.6033015436358361, 'adx_th': 18, 'vol_q': 0.5941114630557051}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:41,994] Trial 56 finished with value: 0.9100548334149003 and parameters: {'n_estimators': 211, 'max_depth': 10, 'learning_rate': 0.09579095939317872, 'subsample': 0.8420184507181082, 'colsample_bytree': 0.6151322893162808, 'gamma': 0.10964304001046832, 'reg_alpha': 0.2485411771600018, 'reg_lambda': 1.4449030106367406, 'threshold': 0.601697244432433, 'adx_th': 18, 'vol_q': 0.56471516104046}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:44,301] Trial 57 finished with value: 0.7577962178951854 and parameters: {'n_estimators': 210, 'max_depth': 10, 'learning_rate': 0.09344434591948234, 'subsample': 0.8427718718238663, 'colsample_bytree': 0.6148668385929736, 'gamma': 0.1080301045258839, 'reg_alpha': 0.23431163589238554, 'reg_lambda': 1.4569952764773033, 'threshold': 0.6504486844393487, 'adx_th': 18, 'vol_q': 0.5457577106043299}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:46,576] Trial 58 finished with value: 0.7642564911363303 and parameters: {'n_estimators': 187, 'max_depth': 10, 'learning_rate': 0.07731612580874274, 'subsample': 0.9163069097753882, 'colsample_bytree': 0.6166283171446122, 'gamma': 0.15096577704461855, 'reg_alpha': 0.16213984417223826, 'reg_lambda': 1.6572583230137314, 'threshold': 0.6011144918121852, 'adx_th': 16, 'vol_q': 0.500849374787493}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:50,318] Trial 59 finished with value: 0.8609750499527916 and parameters: {'n_estimators': 253, 'max_depth': 10, 'learning_rate': 0.11761934433130124, 'subsample': 0.863087070217086, 'colsample_bytree': 0.7673684118792585, 'gamma': 0.06952625968459368, 'reg_alpha': 0.2023266072876978, 'reg_lambda': 1.7856652968196907, 'threshold': 0.6247006643169521, 'adx_th': 17, 'vol_q': 0.572450187278903}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:53,520] Trial 60 finished with value: 0.8087119809856279 and parameters: {'n_estimators': 173, 'max_depth': 8, 'learning_rate': 0.0845856667810942, 'subsample': 0.8253665413154142, 'colsample_bytree': 0.6012774809224809, 'gamma': 0.13091307311191483, 'reg_alpha': 0.10212540172759932, 'reg_lambda': 1.26680775422843, 'threshold': 0.6112524042584885, 'adx_th': 14, 'vol_q': 0.6008496599749462}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:55,521] Trial 61 finished with value: 0.8398511896860548 and parameters: {'n_estimators': 168, 'max_depth': 9, 'learning_rate': 0.1069352724830193, 'subsample': 0.8123379457555365, 'colsample_bytree': 0.6346462404390156, 'gamma': 0.06632385429954459, 'reg_alpha': 0.2502203577214653, 'reg_lambda': 1.4550485887964424, 'threshold': 0.5827575598465083, 'adx_th': 19, 'vol_q': 0.5455878641365002}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:57,600] Trial 62 finished with value: 0.8387861904788693 and parameters: {'n_estimators': 239, 'max_depth': 9, 'learning_rate': 0.09743986969179232, 'subsample': 0.844455630464806, 'colsample_bytree': 0.6728919046604881, 'gamma': 0.18243073331303683, 'reg_alpha': 0.2679437818592814, 'reg_lambda': 1.0833986066556653, 'threshold': 0.590697965588711, 'adx_th': 18, 'vol_q': 0.586685350272288}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:48:59,532] Trial 63 finished with value: 0.7513246216661965 and parameters: {'n_estimators': 274, 'max_depth': 8, 'learning_rate': 0.10918555700931258, 'subsample': 0.794101378333508, 'colsample_bytree': 0.6234736555228059, 'gamma': 0.1994315457927634, 'reg_alpha': 0.18249597793057667, 'reg_lambda': 1.014290084732455, 'threshold': 0.6029663718324033, 'adx_th': 16, 'vol_q': 0.6299294459548428}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:01,489] Trial 64 finished with value: 0.845895686023149 and parameters: {'n_estimators': 154, 'max_depth': 9, 'learning_rate': 0.09976743603324298, 'subsample': 0.8713394818699342, 'colsample_bytree': 0.6475052889760613, 'gamma': 0.09997558517829165, 'reg_alpha': 0.3115824535267683, 'reg_lambda': 1.5231907922329495, 'threshold': 0.5716058027722746, 'adx_th': 20, 'vol_q': 0.5986380969095317}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:05,958] Trial 65 finished with value: 0.7518257969094786 and parameters: {'n_estimators': 197, 'max_depth': 10, 'learning_rate': 0.11821955319027369, 'subsample': 0.8918517673349515, 'colsample_bytree': 0.7319040007092513, 'gamma': 0.12079694489607377, 'reg_alpha': 0.45119695724016495, 'reg_lambda': 1.339576545316619, 'threshold': 0.5514332066313197, 'adx_th': 18, 'vol_q': 0.6450894889043755}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:07,959] Trial 66 finished with value: 0.7793805769561629 and parameters: {'n_estimators': 211, 'max_depth': 9, 'learning_rate': 0.1362841945425456, 'subsample': 0.8090857748892808, 'colsample_bytree': 0.9501916403922973, 'gamma': 0.260577254478424, 'reg_alpha': 0.34861330578011207, 'reg_lambda': 1.145574191248849, 'threshold': 0.6289100042679421, 'adx_th': 17, 'vol_q': 0.6143285322217276}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:09,721] Trial 67 finished with value: 0.7468451128336552 and parameters: {'n_estimators': 142, 'max_depth': 7, 'learning_rate': 0.06298577973828196, 'subsample': 0.85712098687627, 'colsample_bytree': 0.8103392313034039, 'gamma': 0.33563874904994384, 'reg_alpha': 0.40721857998335786, 'reg_lambda': 0.9857900290613545, 'threshold': 0.5387291013642678, 'adx_th': 19, 'vol_q': 0.682894722766717}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:11,512] Trial 68 finished with value: 0.9111882511789601 and parameters: {'n_estimators': 157, 'max_depth': 8, 'learning_rate': 0.08894217766429874, 'subsample': 0.7793090007392492, 'colsample_bytree': 0.6664179043983918, 'gamma': 0.16304374950894476, 'reg_alpha': 0.4320171876071118, 'reg_lambda': 1.3519349469928372, 'threshold': 0.6178729740542717, 'adx_th': 21, 'vol_q': 0.5691081289388127}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:13,441] Trial 69 finished with value: 0.7691578958200377 and parameters: {'n_estimators': 189, 'max_depth': 8, 'learning_rate': 0.08726863446183532, 'subsample': 0.7827719755682896, 'colsample_bytree': 0.6121367532415694, 'gamma': 0.15526720410243997, 'reg_alpha': 0.4292755623015475, 'reg_lambda': 1.4075106034895106, 'threshold': 0.6159623271848393, 'adx_th': 25, 'vol_q': 0.5261089777884949}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:15,090] Trial 70 finished with value: 0.8655688947271125 and parameters: {'n_estimators': 132, 'max_depth': 8, 'learning_rate': 0.07383945990779633, 'subsample': 0.7544412543866948, 'colsample_bytree': 0.6330100870183405, 'gamma': 0.173656546774895, 'reg_alpha': 0.46620429360539606, 'reg_lambda': 1.5707519455713708, 'threshold': 0.6562336000500094, 'adx_th': 22, 'vol_q': 0.5560231777230458}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:19,256] Trial 71 finished with value: 0.8417755698857617 and parameters: {'n_estimators': 161, 'max_depth': 9, 'learning_rate': 0.10405738382132915, 'subsample': 0.7280223244137518, 'colsample_bytree': 0.6670422871270362, 'gamma': 0.1343246561082383, 'reg_alpha': 0.48816875144311267, 'reg_lambda': 1.2387836683519031, 'threshold': 0.5972223595244205, 'adx_th': 21, 'vol_q': 0.5803998077062466}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:21,019] Trial 72 finished with value: 0.8383565201667335 and parameters: {'n_estimators': 181, 'max_depth': 8, 'learning_rate': 0.09648504534372222, 'subsample': 0.8317366449575347, 'colsample_bytree': 0.6894359234118661, 'gamma': 0.28191553517283996, 'reg_alpha': 0.44049868596701885, 'reg_lambda': 1.3384019379307357, 'threshold': 0.6083163159155822, 'adx_th': 20, 'vol_q': 0.5727170524158582}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:22,594] Trial 73 finished with value: 0.8746399447280995 and parameters: {'n_estimators': 157, 'max_depth': 7, 'learning_rate': 0.11384946344737022, 'subsample': 0.8001516270449198, 'colsample_bytree': 0.6553325635820996, 'gamma': 0.08109976187072646, 'reg_alpha': 0.45779373910578103, 'reg_lambda': 1.057491671212511, 'threshold': 0.5810278236063612, 'adx_th': 18, 'vol_q': 0.6074603365054632}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:24,050] Trial 74 finished with value: 0.8277254131153157 and parameters: {'n_estimators': 144, 'max_depth': 7, 'learning_rate': 0.11965137797642697, 'subsample': 0.8008282337365189, 'colsample_bytree': 0.6510975764723447, 'gamma': 0.08227860864947126, 'reg_alpha': 0.4578775646902549, 'reg_lambda': 1.0954067814892356, 'threshold': 0.6184178484950668, 'adx_th': 18, 'vol_q': 0.613227926138575}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:25,768] Trial 75 finished with value: 0.7869315269190752 and parameters: {'n_estimators': 171, 'max_depth': 7, 'learning_rate': 0.1301150862892035, 'subsample': 0.8179322949578327, 'colsample_bytree': 0.6599497920679418, 'gamma': 0.036404097665814594, 'reg_alpha': 0.4830248393580019, 'reg_lambda': 1.5147660808610777, 'threshold': 0.5612950751053103, 'adx_th': 17, 'vol_q': 0.5412088679732243}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:27,020] Trial 76 finished with value: 0.7563129569689817 and parameters: {'n_estimators': 155, 'max_depth': 6, 'learning_rate': 0.11185496636012758, 'subsample': 0.7783612597700925, 'colsample_bytree': 0.6224804941707345, 'gamma': 0.23686763074558548, 'reg_alpha': 0.4982408676367417, 'reg_lambda': 1.426963123494912, 'threshold': 0.6993829026431896, 'adx_th': 19, 'vol_q': 0.5929585521977376}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:28,453] Trial 77 finished with value: 0.8644196542771375 and parameters: {'n_estimators': 220, 'max_depth': 5, 'learning_rate': 0.08926386518767597, 'subsample': 0.7622449791386389, 'colsample_bytree': 0.6381379173192506, 'gamma': 0.0416818771767657, 'reg_alpha': 0.4189974502532257, 'reg_lambda': 1.3694026453194375, 'threshold': 0.58459174273568, 'adx_th': 25, 'vol_q': 0.6633398931791702}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:31,622] Trial 78 finished with value: 0.8596140414495149 and parameters: {'n_estimators': 130, 'max_depth': 7, 'learning_rate': 0.1397422260820823, 'subsample': 0.7934980714596104, 'colsample_bytree': 0.6817082743134067, 'gamma': 0.07817413310804779, 'reg_alpha': 0.4491905806660925, 'reg_lambda': 1.192197777158905, 'threshold': 0.6383516676466163, 'adx_th': 16, 'vol_q': 0.570145120522674}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:34,075] Trial 79 finished with value: 0.7556804328513884 and parameters: {'n_estimators': 157, 'max_depth': 8, 'learning_rate': 0.08073459719389792, 'subsample': 0.7407795305280812, 'colsample_bytree': 0.6941432023861885, 'gamma': 0.08796179541105928, 'reg_alpha': 0.4705877685639845, 'reg_lambda': 1.1139369431473898, 'threshold': 0.5944372728376925, 'adx_th': 15, 'vol_q': 0.6461358742186668}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:36,079] Trial 80 finished with value: 0.5715463789556977 and parameters: {'n_estimators': 202, 'max_depth': 8, 'learning_rate': 0.1278389530187097, 'subsample': 0.8240821606072402, 'colsample_bytree': 0.7071146944723026, 'gamma': 0.05143650065615488, 'reg_alpha': 0.2248592210184655, 'reg_lambda': 0.9199561572311195, 'threshold': 0.631206813352072, 'adx_th': 24, 'vol_q': 0.8190430671210035}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:37,856] Trial 81 finished with value: 0.8266931911656655 and parameters: {'n_estimators': 144, 'max_depth': 9, 'learning_rate': 0.10299570372297417, 'subsample': 0.8055530173729002, 'colsample_bytree': 0.6546547358479382, 'gamma': 0.11295681948264905, 'reg_alpha': 0.396326792468999, 'reg_lambda': 1.0547119542506584, 'threshold': 0.5775077054555717, 'adx_th': 20, 'vol_q': 0.6285978510616038}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:39,731] Trial 82 finished with value: 0.797828193498603 and parameters: {'n_estimators': 178, 'max_depth': 9, 'learning_rate': 0.119304928997323, 'subsample': 0.8451161094131775, 'colsample_bytree': 0.672057833004287, 'gamma': 0.1351760298409336, 'reg_alpha': 0.4827042403780155, 'reg_lambda': 1.2901316231354738, 'threshold': 0.569910519421175, 'adx_th': 18, 'vol_q': 0.6062355355412808}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:41,225] Trial 83 finished with value: 0.6957679065140495 and parameters: {'n_estimators': 164, 'max_depth': 10, 'learning_rate': 0.11237485729195386, 'subsample': 0.7833327921043372, 'colsample_bytree': 0.6409644944850128, 'gamma': 0.32197859304876686, 'reg_alpha': 0.4632363860382677, 'reg_lambda': 0.8554292733742812, 'threshold': 0.5562063381793312, 'adx_th': 17, 'vol_q': 0.6349656383439541}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:43,145] Trial 84 finished with value: 0.7546621573265758 and parameters: {'n_estimators': 121, 'max_depth': 8, 'learning_rate': 0.09453660632733354, 'subsample': 0.8142998083492751, 'colsample_bytree': 0.6800999054251633, 'gamma': 0.16948834748652458, 'reg_alpha': 0.4273293696724568, 'reg_lambda': 1.028473887629908, 'threshold': 0.604324445880561, 'adx_th': 21, 'vol_q': 0.6197553262161095}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:46,312] Trial 85 finished with value: 0.7853251328215878 and parameters: {'n_estimators': 139, 'max_depth': 7, 'learning_rate': 0.1084616809665786, 'subsample': 0.7674560056869925, 'colsample_bytree': 0.6619825114219828, 'gamma': 0.4425296908201774, 'reg_alpha': 0.29224705832953296, 'reg_lambda': 1.1716112870303736, 'threshold': 0.6198138938573318, 'adx_th': 19, 'vol_q': 0.6557433246638981}. Best is trial 35 with value: 0.9193775188695789.
# [I 2026-04-25 04:49:47,399] Trial 86 finished with value: 0.9470384225188201 and parameters: {'n_estimators': 106, 'max_depth': 9, 'learning_rate': 0.18124892517632946, 'subsample': 0.8343883572027586, 'colsample_bytree': 0.6083906068445171, 'gamma': 0.19817850560364708, 'reg_alpha': 0.4454542024710449, 'reg_lambda': 0.7679023644985573, 'threshold': 0.5798915503225239, 'adx_th': 22, 'vol_q': 0.5904850788097367}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:48,997] Trial 87 finished with value: 0.8853816127840984 and parameters: {'n_estimators': 108, 'max_depth': 9, 'learning_rate': 0.047208386566895265, 'subsample': 0.835629599932556, 'colsample_bytree': 0.6072385996349005, 'gamma': 0.20133501680327764, 'reg_alpha': 0.4454670825193605, 'reg_lambda': 0.7397368177965353, 'threshold': 0.5976569143734035, 'adx_th': 22, 'vol_q': 0.5603680251991394}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:50,045] Trial 88 finished with value: 0.8827056303278192 and parameters: {'n_estimators': 105, 'max_depth': 9, 'learning_rate': 0.1865457868047625, 'subsample': 0.8385682517170491, 'colsample_bytree': 0.6098610557678436, 'gamma': 0.2236682331721487, 'reg_alpha': 0.40278473040315554, 'reg_lambda': 0.611853338117502, 'threshold': 0.5968857936809853, 'adx_th': 23, 'vol_q': 0.5588288228766651}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:51,137] Trial 89 finished with value: 0.7209971904170321 and parameters: {'n_estimators': 105, 'max_depth': 10, 'learning_rate': 0.18332169107588153, 'subsample': 0.8349567339738068, 'colsample_bytree': 0.6075791564125638, 'gamma': 0.20544772367402422, 'reg_alpha': 0.44000339054871557, 'reg_lambda': 0.5762095759713264, 'threshold': 0.5901949684078924, 'adx_th': 22, 'vol_q': 0.5589712080424962}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:52,174] Trial 90 finished with value: 0.763392781683061 and parameters: {'n_estimators': 112, 'max_depth': 9, 'learning_rate': 0.19345092244060327, 'subsample': 0.8509773982669754, 'colsample_bytree': 0.6049768596558828, 'gamma': 0.2354352147588694, 'reg_alpha': 0.4085954574796818, 'reg_lambda': 0.6835781760445793, 'threshold': 0.5964781497114051, 'adx_th': 23, 'vol_q': 0.530789269441999}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:53,226] Trial 91 finished with value: 0.8646946206199893 and parameters: {'n_estimators': 104, 'max_depth': 9, 'learning_rate': 0.1759312766503141, 'subsample': 0.8689186511273548, 'colsample_bytree': 0.6249049132083007, 'gamma': 0.2162771764186936, 'reg_alpha': 0.4442336400648431, 'reg_lambda': 0.7556704882919338, 'threshold': 0.6099725175022737, 'adx_th': 23, 'vol_q': 0.549823352332119}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:54,943] Trial 92 finished with value: 0.8376004823545301 and parameters: {'n_estimators': 118, 'max_depth': 9, 'learning_rate': 0.04462981976339579, 'subsample': 0.8601518961962025, 'colsample_bytree': 0.6002227717990403, 'gamma': 0.18977866216442865, 'reg_alpha': 0.4758532107441148, 'reg_lambda': 0.7938265891798617, 'threshold': 0.6258906753855793, 'adx_th': 24, 'vol_q': 0.5770879274105115}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:56,502] Trial 93 finished with value: 0.7925742707024037 and parameters: {'n_estimators': 129, 'max_depth': 9, 'learning_rate': 0.1986790620753772, 'subsample': 0.8822725440666025, 'colsample_bytree': 0.6160839817563993, 'gamma': 0.14515907662199154, 'reg_alpha': 0.42628253886918926, 'reg_lambda': 0.6338828093938398, 'threshold': 0.5994901898807015, 'adx_th': 22, 'vol_q': 0.5367445569485415}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:49:59,536] Trial 94 finished with value: 0.7656250438825762 and parameters: {'n_estimators': 101, 'max_depth': 9, 'learning_rate': 0.17573973729079106, 'subsample': 0.8320447497559035, 'colsample_bytree': 0.6306805907417302, 'gamma': 0.17238408144114914, 'reg_alpha': 0.4908008247033263, 'reg_lambda': 0.5952607162746619, 'threshold': 0.6055079634098509, 'adx_th': 24, 'vol_q': 0.5131146667446793}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:50:01,303] Trial 95 finished with value: 0.9211800696113072 and parameters: {'n_estimators': 108, 'max_depth': 10, 'learning_rate': 0.03762776828308977, 'subsample': 0.8202306848263841, 'colsample_bytree': 0.6171094456245487, 'gamma': 0.21807980095669272, 'reg_alpha': 0.4659333577117138, 'reg_lambda': 0.7216495407670165, 'threshold': 0.586525830234537, 'adx_th': 23, 'vol_q': 0.5888630395991516}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:50:03,179] Trial 96 finished with value: 0.8016410869445799 and parameters: {'n_estimators': 111, 'max_depth': 10, 'learning_rate': 0.031153594212132416, 'subsample': 0.8405740035015373, 'colsample_bytree': 0.6110523138025511, 'gamma': 0.26310867988814196, 'reg_alpha': 0.46665343129877784, 'reg_lambda': 0.7128487332162757, 'threshold': 0.587047576090433, 'adx_th': 22, 'vol_q': 0.5620655658891911}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:50:05,255] Trial 97 finished with value: 0.6386417171364388 and parameters: {'n_estimators': 124, 'max_depth': 10, 'learning_rate': 0.03560441099793548, 'subsample': 0.8269982050976205, 'colsample_bytree': 0.6459724736899618, 'gamma': 0.21520546058941484, 'reg_alpha': 0.4992421505688918, 'reg_lambda': 0.5410856914963414, 'threshold': 0.5659067630265704, 'adx_th': 23, 'vol_q': 0.6964843289767585}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:50:06,956] Trial 98 finished with value: 0.8741920518204654 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.04979525768927406, 'subsample': 0.8487455117297016, 'colsample_bytree': 0.6320098107130037, 'gamma': 0.24631452968655565, 'reg_alpha': 0.4819457246088719, 'reg_lambda': 0.7452782367399775, 'threshold': 0.5745610153067892, 'adx_th': 22, 'vol_q': 0.5899410286365517}. Best is trial 86 with value: 0.9470384225188201.
# [I 2026-04-25 04:50:08,342] Trial 99 finished with value: 0.7214978769685914 and parameters: {'n_estimators': 116, 'max_depth': 10, 'learning_rate': 0.1685187112339922, 'subsample': 0.7894618084074896, 'colsample_bytree': 0.8415147254479535, 'gamma': 0.2259728840716806, 'reg_alpha': 0.4155210751239328, 'reg_lambda': 0.6522455688979976, 'threshold': 0.61412063289771, 'adx_th': 23, 'vol_q': 0.670433589790665}. Best is trial 86 with value: 0.9470384225188201.
# {'n_estimators': 106, 'max_depth': 9, 'learning_rate': 0.18124892517632946, 'subsample': 0.8343883572027586, 'colsample_bytree': 0.6083906068445171, 'gamma': 0.19817850560364708, 'reg_alpha': 0.4454542024710449, 'reg_lambda': 0.7679023644985573, 'threshold': 0.5798915503225239, 'adx_th': 22, 'vol_q': 0.5904850788097367}

# %%
print("proba exists:", "proba" in globals())
# Out:
# proba exists: False

# %%
best_params = study.best_params
print(best_params)  # 念のため確認

model_params = {
    k: best_params[k] for k in [
        'n_estimators','max_depth','learning_rate',
        'subsample','colsample_bytree',
        'gamma','reg_alpha','reg_lambda'
    ]
}

strategy_params = {
    "threshold": best_params["threshold"],
    "adx_th": best_params["adx_th"],
    "vol_q": best_params["vol_q"]
}
# Out:
# {'n_estimators': 106, 'max_depth': 9, 'learning_rate': 0.18124892517632946, 'subsample': 0.8343883572027586, 'colsample_bytree': 0.6083906068445171, 'gamma': 0.19817850560364708, 'reg_alpha': 0.4454542024710449, 'reg_lambda': 0.7679023644985573, 'threshold': 0.5798915503225239, 'adx_th': 22, 'vol_q': 0.5904850788097367}

# %%
model = XGBClassifier(
    **model_params,
    random_state=42,
    eval_metric='logloss',
    n_jobs=-1
)

# %%
# ======================
# 最終モデル + 最終バックテスト
# ======================

from xgboost import XGBClassifier

# --- Optunaの最適パラメータ取得 ---
best_params = study.best_params.copy()

# thresholdは別で使う
best_threshold = best_params.pop('threshold')

print("Best threshold:", best_threshold)
print("Best model params:", best_params)

# ======================
# モデル再学習（全訓練データ）
# ======================

# SMOTE（訓練データのみ）
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# モデル作成
final_model = XGBClassifier(
    **best_params,
    random_state=42,
    eval_metric='logloss',
    n_jobs=-1
)

# 学習
final_model.fit(X_train_resampled, y_train_resampled)

# ======================
# 予測
# ======================

proba_final = final_model.predict_proba(X_test)[:, 1]

# ======================
# 戦略（最適threshold）
# ======================

strategy_final = (proba_final > best_threshold).astype(int)

# Series化（重要）
signals_final = pd.Series(strategy_final, index=X_test.index)

# ======================
# バックテスト
# ======================

results_final, equity_final = run_backtest(df, X_test, signals_final)

# ======================
# 結果表示
# ======================

print("===== FINAL RESULT =====")
for k, v in results_final.items():
    print(f"{k}: {v}")
# Out:
# Best threshold: 0.5798915503225239
# Best model params: {'n_estimators': 106, 'max_depth': 9, 'learning_rate': 0.18124892517632946, 'subsample': 0.8343883572027586, 'colsample_bytree': 0.6083906068445171, 'gamma': 0.19817850560364708, 'reg_alpha': 0.4454542024710449, 'reg_lambda': 0.7679023644985573, 'adx_th': 22, 'vol_q': 0.5904850788097367}
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [04:50:28] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "adx_th", "vol_q" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ===== FINAL RESULT =====
# Final Balance: 117401.24272062126
# Total Return (%): 17.40124272062127
# Total Trades: 13
# Win Rate (%): 53.84615384615385

# %%
import matplotlib.pyplot as plt

plt.plot(equity_final)
plt.title("Final Strategy Equity Curve")
plt.show()

# %%
# ======================
# 時系列CVで最終戦略を検証
# ======================

from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import pandas as pd

tscv = TimeSeriesSplit(n_splits=5)

results_list = []
equity_curves = []

# --- Optunaの最適パラメータ取得 (best_params はグローバルに存在すると仮定) ---
# best_params は既に study.best_params として定義されているはず
# Freshly get best_params from study to avoid prior modifications
best_params_cv = study.best_params.copy()

for fold, (train_idx, test_idx) in enumerate(tscv.split(X)):

    print(f"\n===== Fold {fold+1} ====")

    X_train_cv, X_test_cv = X.iloc[train_idx], X.iloc[test_idx]
    y_train_cv, y_test_cv = y.iloc[train_idx], y.iloc[test_idx]

    # --- SMOTE（訓練データのみ） ---
    smote = SMOTE(random_state=42)
    X_train_res, y_train_res = smote.fit_resample(X_train_cv, y_train_cv)

    # --- モデル（Optunaの最適パラメータ） ---
    # best_params_cvには'threshold', 'adx_th', 'vol_q'が含まれるので、
    # モデルパラメータから除外してXGBClassifierに渡す
    model_params_for_xgb = {k: best_params_cv[k] for k in best_params_cv if k not in [
        'threshold','adx_th','vol_q'
    ]}

    # Initialize model for each fold
    model = XGBClassifier(
        **model_params_for_xgb,
        random_state=42,
        eval_metric='logloss',
        n_jobs=-1
    )

    model.fit(X_train_res, y_train_res)

    # --- 予測 ---
    proba = model.predict_proba(X_test_cv)[:, 1]

    # --- 戦略 ---
    df_slice = df.loc[X_test_cv.index].copy()
    df_slice['proba'] = proba
    # ADXとVolatility_Shortはdf_sliceに存在しない場合があるので、dfから取得
    df_slice['ADX'] = df.loc[X_test_cv.index, 'ADX']
    df_slice['Volatility_Short'] = df.loc[X_test_cv.index, 'Volatility_Short']
    # MACDとSignal_Lineは戦略には直接使用しないが、df_sliceに含める場合はここで追加
    # df_slice['MACD'] = df.loc[X_test_cv.index, 'MACD']
    # df_slice['Signal_Line'] = df.loc[X_test_cv.index, 'Signal_Line']

    vol_threshold = df_slice['Volatility_Short'].quantile(best_params_cv["vol_q"])

    signals = (
        (df_slice['proba'] > best_params_cv["threshold"]) &
        (df_slice['ADX'] > best_params_cv["adx_th"]) &
        (df_slice['Volatility_Short'] > vol_threshold)
    ).astype(int)

    # --- バックテスト ---
    results, equity = run_backtest(df, X_test_cv, signals)

    results_list.append(results)
    equity_curves.append(equity)

    print(results)

# ======================
# 結果まとめ
# ======================

df_results = pd.DataFrame(results_list)

print("\n===== CV SUMMARY ====")
print(df_results.mean())
print("\nSTD:")
print(df_results.std())
# Out:
# ===== Fold 1 ====
# {'Final Balance': np.float64(104943.7348270564), 'Total Return (%)': np.float64(4.94373482705639), 'Total Trades': 5, 'Win Rate (%)': 60.0}
#
# ===== Fold 2 ====
# {'Final Balance': np.float64(101367.57163916259), 'Total Return (%)': np.float64(1.3675716391625903), 'Total Trades': 8, 'Win Rate (%)': 50.0}
#
# ===== Fold 3 ====
# {'Final Balance': np.float64(103403.32180081916), 'Total Return (%)': np.float64(3.40332180081917), 'Total Trades': 7, 'Win Rate (%)': 42.857142857142854}
#
# ===== Fold 4 ====
# {'Final Balance': np.float64(98904.2694729224), 'Total Return (%)': np.float64(-1.0957305270775985), 'Total Trades': 6, 'Win Rate (%)': 50.0}
#
# ===== Fold 5 ====
# {'Final Balance': np.float64(111328.12201374472), 'Total Return (%)': np.float64(11.328122013744713), 'Total Trades': 5, 'Win Rate (%)': 80.0}
#
# ===== CV SUMMARY ====
# Final Balance       103989.403951
# Total Return (%)         3.989404
# Total Trades             6.200000
# Win Rate (%)            56.571429
# dtype: float64
#
# STD:
# Final Balance       4686.246362
# Total Return (%)       4.686246
# Total Trades           1.303840
# Win Rate (%)          14.449066
# dtype: float64

# %%
print('ADX' in df.columns)
print(df.columns)
# Out:
# True
# Index(['Close', 'High', 'Low', 'Volume', 'SMA_5', 'SMA_25', 'SMA_DIFF',
#        'SMA_RATIO', 'Target', 'RSI', 'MACD', 'Signal_Line', 'MACD_Hist',
#        'Daily_Return', 'Volatility_Short', 'ATR', 'ADX', 'Upper_BB',
#        'Lower_BB', 'BB_Width', 'Close_Lag_1', 'Close_Lag_2', 'Close_Lag_3',
#        'Close_Lag_4', 'Close_Lag_5'],
#       dtype='object')
