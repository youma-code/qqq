# %% [markdown]
# <a href="https://colab.research.google.com/github/youma-code/qqq/blob/main/1.0.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import time


# ======================
# データ取得
# ======================
ticker = "AAPL"
start_date = "2020-01-01"
end_date = pd.to_datetime("today").strftime("%Y-%m-%d")

def download_data(ticker, start, end):
    for _ in range(5):
        df = yf.download(ticker, start=start, end=end)
        if not df.empty:
            return df
        time.sleep(3)
    return pd.DataFrame()

df = download_data(ticker, start_date, end_date)

# Handle potential MultiIndex from yfinance to ensure df['Close'] is a Series
if isinstance(df.columns, pd.MultiIndex):
    df = df[['Close', 'High', 'Low', 'Volume']].droplevel(level=1, axis=1)
else:
    df = df[['Close', 'High', 'Low', 'Volume']].copy() # Use .copy() to avoid SettingWithCopyWarning
df.columns = ['Close', 'High', 'Low', 'Volume'] # Ensure column names are simple strings
df.dropna(inplace=True)

# ======================
# 特徴量作成
# ======================

# SMA
df['SMA_5'] = df['Close'].rolling(5).mean()
df['SMA_25'] = df['Close'].rolling(25).mean()
df['SMA_DIFF'] = df['SMA_5'] - df['SMA_25']
df['SMA_RATIO'] = df['SMA_5'] / df['SMA_25']

# Target
future_max = df['Close'].shift(-1).rolling(3).max()
df['Target'] = ((future_max / df['Close'] - 1) > 0.0075).astype(int)

# RSI
delta = df['Close'].diff()
gain = delta.clip(lower=0).rolling(14).mean()
loss = (-delta.clip(upper=0)).rolling(14).mean()
rs = gain / loss
df['RSI'] = 100 - (100 / (1 + rs))

# MACD
ema12 = df['Close'].ewm(span=12).mean()
ema26 = df['Close'].ewm(span=26).mean()
df['MACD'] = ema12 - ema26
df['Signal_Line'] = df['MACD'].ewm(span=9).mean()
df['MACD_Hist'] = df['MACD'] - df['Signal_Line']

df['Daily_Return'] = df['Close'].pct_change()
df['Volatility_Short'] = df['Daily_Return'].rolling(5).std()


# ATR
tr = pd.concat([
    df['High'] - df['Low'],
    abs(df['High'] - df['Close'].shift()),
    abs(df['Low'] - df['Close'].shift())
], axis=1).max(axis=1)

df['ATR'] = tr.rolling(14).mean()

# ======================
# ADX（トレンド強さ）
# ======================

window = 14

high = df['High']
low = df['Low']
close = df['Close']

plus_dm = high.diff()
minus_dm = -low.diff()

plus_dm[plus_dm < 0] = 0
minus_dm[minus_dm < 0] = 0

tr = pd.concat([
    high - low,
    (high - close.shift()).abs(),
    (low - close.shift()).abs()
], axis=1).max(axis=1)

atr = tr.rolling(window).mean()

plus_di = 100 * (plus_dm.rolling(window).mean() / atr)
minus_di = 100 * (minus_dm.rolling(window).mean() / atr)

dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100

df['ADX'] = dx.rolling(window).mean()

# ボリンジャー
# Ensure ma and std are Series by using .squeeze() if they result in single-column DataFrames
ma = df['Close'].rolling(20).mean().squeeze()
std = df['Close'].rolling(20).std().squeeze()

df['Upper_BB'] = ma + 2 * std
df['Lower_BB'] = ma - 2 * std
df['BB_Width'] = (df['Upper_BB'] - df['Lower_BB']) / ma

# ラグ
for lag in range(1, 6):
    df[f'Close_Lag_{lag}'] = df['Close'].shift(lag)

# 最後にNaN削除
df.dropna(inplace=True)

print("セル1完了:", df.shape)
# Out:
# /tmp/ipykernel_29949/3527103283.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# セル1完了: (1558, 25)

# %%
# ======================
# 特徴量リスト（固定）
# ======================

features = [
    'SMA_5', 'SMA_25', 'SMA_DIFF', 'SMA_RATIO',
    'RSI', 'MACD', 'Signal_Line', 'MACD_Hist',
    'ATR',
    'Upper_BB', 'Lower_BB', 'BB_Width',
    'Volatility_Short',
    'ADX'  # ←これ追加
]
# ラグ特徴量（セル1で作ったやつに対応）
for lag in range(1, 6):
    features.append(f'Close_Lag_{lag}')

# 存在しない列があったら弾く（安全対策）
features = [f for f in features if f in df.columns]

print("使用特徴量数:", len(features))
print(features[:10])
# Out:
# 使用特徴量数: 19
# ['SMA_5', 'SMA_25', 'SMA_DIFF', 'SMA_RATIO', 'RSI', 'MACD', 'Signal_Line', 'MACD_Hist', 'ATR', 'Upper_BB']

# %%
# ======================
# X, y 作成
# ======================

# 念のためチェック
assert 'Target' in df.columns, "Target列が存在しません"

# Xとy
X = df[features].copy()
y = df['Target'].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
print("Target分布:")
print(y.value_counts(normalize=True))
# Out:
# X shape: (1558, 19)
# y shape: (1558,)
# Target分布:
# Target
# 0    0.516046
# 1    0.483954
# Name: proportion, dtype: float64

# %%
X = df[features]
y = df['Target']
print(f"X and y defined. Feature matrix shape: {X.shape}")
# Out:
# X and y defined. Feature matrix shape: (1558, 19)

# %%
# ======================
# 時系列分割
# ======================

split_index = int(len(df) * 0.8)

X_train = X.iloc[:split_index].copy()
X_test  = X.iloc[split_index:].copy()

y_train = y.iloc[:split_index].copy()
y_test  = y.iloc[split_index:].copy()

print("Train期間:", X_train.index.min(), "→", X_train.index.max())
print("Test期間 :", X_test.index.min(), "→", X_test.index.max())

print("Train size:", X_train.shape)
print("Test size :", X_test.shape)
# Out:
# Train期間: 2020-02-11 00:00:00 → 2025-01-24 00:00:00
# Test期間 : 2025-01-27 00:00:00 → 2026-04-23 00:00:00
# Train size: (1246, 19)
# Test size : (312, 19)

# %%
# ======================
# SMOTE（訓練データのみ）
# ======================

from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", y_train.value_counts())
print("After SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Before SMOTE: Target
# 1    631
# 0    615
# Name: count, dtype: int64
# After SMOTE:
# Target
# 1    631
# 0    631
# Name: count, dtype: int64

# %%
# ======================
# RandomForest チューニング
# ======================

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# モデル定義
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# パラメータ範囲
param_dist_rf = {
    'n_estimators': randint(100, 500),
    'max_depth': randint(3, 20),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 5),
    'max_features': ['sqrt', 'log2', None]
}

# チューニング
random_search_rf = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist_rf,
    n_iter=30,                # 最初は軽めでOK（後で増やせる）
    scoring='f1',             # 不均衡データ向け
    cv=3,                     # 時系列じゃない簡易CV（後で改善）
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# 学習（SMOTE後データ使う）
random_search_rf.fit(X_train_resampled, y_train_resampled)

# 最適モデル
model_rf_tuned = random_search_rf.best_estimator_

print("Best params:", random_search_rf.best_params_)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best params: {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 180}

# %%
# ======================
# XGBoost チューニング
# ======================

from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# モデル定義
xgb = XGBClassifier(
    random_state=42,
    eval_metric='logloss',
    n_jobs=-1
)

# パラメータ範囲
param_dist_xgb = {
    'n_estimators': randint(100, 500),
    'max_depth': randint(3, 12),
    'learning_rate': uniform(0.01, 0.2),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 0.5),
    'reg_alpha': uniform(0, 0.5),
    'reg_lambda': uniform(0.5, 1.5)
}

# チューニング
random_search_xgb = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist_xgb,
    n_iter=30,          # 最初は軽め
    scoring='f1',
    cv=3,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# 学習（SMOTE後データ）
random_search_xgb.fit(X_train_resampled, y_train_resampled)

# 最適モデル
model_xgb_tuned = random_search_xgb.best_estimator_

print("Best params:", random_search_xgb.best_params_)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Best params: {'colsample_bytree': np.float64(0.9551080395043839), 'gamma': np.float64(0.42546422438375636), 'learning_rate': np.float64(0.19712699884418952), 'max_depth': 6, 'n_estimators': 203, 'reg_alpha': np.float64(0.30321452982979497), 'reg_lambda': np.float64(0.5137955774249445), 'subsample': np.float64(0.6405886171464128)}

# %%
# ======================
# 予測確率の取得
# ======================

# RandomForest
proba_class1_rf = model_rf_tuned.predict_proba(X_test)[:, 1]

# XGBoost
proba_class1_xgb = model_xgb_tuned.predict_proba(X_test)[:, 1]

# 確認
print("RF proba shape:", proba_class1_rf.shape)
print("XGB proba shape:", proba_class1_xgb.shape)
# Out:
# RF proba shape: (312,)
# XGB proba shape: (312,)

# %%
# ======================
# 戦略A・Bの定義
# ======================

# 閾値（あとで調整可能）
threshold = 0.6

# --- 戦略A：AND条件（両モデルが強気） ---
strategy_A = (
    (proba_class1_rf > threshold) &
    (proba_class1_xgb > threshold)
).astype(int)

# --- 戦略B：XGBoost重視 ---
strategy_B = (
    (proba_class1_xgb > threshold)
).astype(int)

# 確認
print("Strategy A trades:", strategy_A.sum())
print("Strategy B trades:", strategy_B.sum())
# Out:
# Strategy A trades: 20
# Strategy B trades: 84

# %%
# ======================
# バックテスト関数（統一版）
# ======================

def run_backtest(df, X_test, signals, initial_balance=100000, risk_per_trade=0.02):

    # --- テスト期間のデータだけ使う ---
    df_bt = df.loc[X_test.index].copy()

    # --- 必須列チェック ---
    required_cols = ['Close', 'ATR']
    df_bt = df_bt.dropna(subset=required_cols)

    # signalsも同じindexに揃える
    signals = signals.loc[df_bt.index]

    # --- 初期化 ---
    balance = initial_balance
    equity_curve = []
    position = 0
    entry_price = 0
    trade_count = 0
    win_count = 0

    for i in range(len(df_bt) - 1):
        row = df_bt.iloc[i]
        next_row = df_bt.iloc[i + 1]

        signal = signals.iloc[i]

        # ======================
        # エントリー
        # ======================
        if position == 0 and signal == 1:

            # ATR-based position sizing
            atr = row['ATR']
            if pd.isna(atr) or atr == 0:
                continue

            risk_amount = balance * risk_per_trade
            stop_loss_distance = atr * 2

            position_size = risk_amount / stop_loss_distance

            entry_price = next_row['Close']
            position = position_size
            trade_count += 1

        # ======================
        # ポジション保有中
        # ======================
        elif position > 0:

            current_price = next_row['Close']

            # ストップロス
            stop_price = entry_price - (row['ATR'] * 2)

            # 利確（リスクリワード 1:2）
            take_profit_price = entry_price + (row['ATR'] * 4)

            exit_flag = False

            if current_price <= stop_price:
                exit_flag = True
            elif current_price >= take_profit_price:
                exit_flag = True

            if exit_flag:
                pnl = (current_price - entry_price) * position
                balance += pnl

                if pnl > 0:
                    win_count += 1

                position = 0

        equity_curve.append(balance)

    # --- 最後のポジション強制決済 ---
    if position > 0:
        final_price = df_bt.iloc[-1]['Close']
        pnl = (final_price - entry_price) * position
        balance += pnl

        if pnl > 0:
            win_count += 1

    # --- 結果まとめ ---
    win_rate = (win_count / trade_count * 100) if trade_count > 0 else 0
    total_return = (balance / initial_balance - 1) * 100

    results = {
        'Final Balance': balance,
        'Total Return (%)': total_return,
        'Total Trades': trade_count,
        'Win Rate (%)': win_rate
    }

    return results, equity_curve

# %%
# ======================
# バックテスト実行
# ======================

import pandas as pd

# signalsをSeriesに変換（超重要）
signals_A = pd.Series(strategy_A, index=X_test.index)
signals_B = pd.Series(strategy_B, index=X_test.index)

# --- 戦略A ---
results_A, equity_A = run_backtest(df, X_test, signals_A)

# --- 戦略B ---
results_B, equity_B = run_backtest(df, X_test, signals_B)

# 結果表示
print("===== Strategy A =====")
for k, v in results_A.items():
    print(f"{k}: {v}")

print("\n===== Strategy B =====")
for k, v in results_B.items():
    print(f"{k}: {v}")
# Out:
# ===== Strategy A =====
# Final Balance: 106990.13589711256
# Total Return (%): 6.990135897112548
# Total Trades: 5
# Win Rate (%): 60.0
#
# ===== Strategy B =====
# Final Balance: 118841.70732772378
# Total Return (%): 18.84170732772379
# Total Trades: 13
# Win Rate (%): 53.84615384615385

# %%
import matplotlib.pyplot as plt

plt.plot(equity_A, label="Strategy A")
plt.plot(equity_B, label="Strategy B")

plt.legend()
plt.title("Equity Curve")
plt.show()

# %%
import optuna
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE


# ======================
# 評価指標
# ======================
def calc_metrics(equity):
    equity = np.array(equity)

    returns = np.diff(equity)
    gains = returns[returns > 0].sum()
    losses = -returns[returns < 0].sum() + 1e-9

    profit_factor = gains / losses

    peak = np.maximum.accumulate(equity)
    dd = (equity - peak) / peak
    max_dd = abs(dd.min())

    return profit_factor, max_dd


# ======================
# Optuna
# ======================
def objective(trial):

    model_params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 400),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 0.5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 0.5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.5, 2.0),
    }

    threshold = trial.suggest_float("threshold", 0.45, 0.7)
    adx_th = trial.suggest_int("adx_th", 10, 25)
    vol_q = trial.suggest_float("vol_q", 0.5, 0.9)

    tscv = TimeSeriesSplit(n_splits=3)

    scores = []

    for train_idx, val_idx in tscv.split(X):

        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train = y.iloc[train_idx]

        smote = SMOTE(random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

        model = XGBClassifier(**model_params, random_state=42, eval_metric='logloss')
        model.fit(X_train_res, y_train_res)

        proba = model.predict_proba(X_val)[:, 1]

        df_slice = df.loc[X_val.index].copy()
        df_slice["proba"] = proba

        vol_threshold = df_slice["Volatility_Short"].quantile(vol_q)

        signals = (
            (df_slice["proba"] > threshold) &
            (df_slice["ADX"] > adx_th) &
            (df_slice["Volatility_Short"] > vol_threshold)
        ).astype(int)

        results, equity = run_backtest(df, X_val, signals)

        # ======================
        # metrics
        # ======================
        trades = results["Total Trades"]
        winrate = results["Win Rate (%)"] / 100

        equity = np.array(equity)
        returns = np.diff(equity) / equity[:-1]

        # PF（簡易）
        gross_profit = np.sum(returns[returns > 0])
        gross_loss = -np.sum(returns[returns < 0]) + 1e-9
        pf = gross_profit / gross_loss

        dd = np.min(equity / np.maximum.accumulate(equity) - 1)

        # ======================
        # スコア（重要）
        # ======================
        score = (
            winrate * 0.4 +
            np.log1p(pf) * 0.3 +
            (1 + dd) * 0.3   # DDはマイナスなので補正
        )

        scores.append(score)

    return np.mean(scores)


# ======================
# 実行
# ======================
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

print(study.best_params)
# Out:
# [I 2026-04-24 20:19:07,227] A new study created in memory with name: no-name-d7bd7a06-7471-44cc-bb65-1f70022f2e1f
# [I 2026-04-24 20:19:09,910] Trial 0 finished with value: 1.6990022433055447 and parameters: {'n_estimators': 359, 'max_depth': 9, 'learning_rate': 0.05835199371127463, 'subsample': 0.6510180450669923, 'colsample_bytree': 0.967917558198546, 'gamma': 0.3878802598758168, 'reg_alpha': 0.23234439975737248, 'reg_lambda': 1.056883711291694, 'threshold': 0.641545415239786, 'adx_th': 18, 'vol_q': 0.656719594801281}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:11,288] Trial 1 finished with value: 1.1460507176317167 and parameters: {'n_estimators': 110, 'max_depth': 10, 'learning_rate': 0.010692111932029808, 'subsample': 0.7269096667829313, 'colsample_bytree': 0.6666049829520153, 'gamma': 0.26562531631153374, 'reg_alpha': 0.2522584743349627, 'reg_lambda': 0.6939364972878344, 'threshold': 0.6739920649998411, 'adx_th': 10, 'vol_q': 0.5169405416477585}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:12,485] Trial 2 finished with value: 1.603237476532241 and parameters: {'n_estimators': 258, 'max_depth': 4, 'learning_rate': 0.0458121258436466, 'subsample': 0.8337683487861965, 'colsample_bytree': 0.9320522808071747, 'gamma': 0.3685068143567641, 'reg_alpha': 0.4130157285665694, 'reg_lambda': 1.8966112362690541, 'threshold': 0.46494576916920816, 'adx_th': 15, 'vol_q': 0.6000322741934749}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:13,445] Trial 3 finished with value: 1.3725221182028446 and parameters: {'n_estimators': 156, 'max_depth': 5, 'learning_rate': 0.03657294335272521, 'subsample': 0.924640956455694, 'colsample_bytree': 0.7758944217758573, 'gamma': 0.14928583783375965, 'reg_alpha': 0.338682226341543, 'reg_lambda': 1.8706400805861658, 'threshold': 0.46790014279314524, 'adx_th': 21, 'vol_q': 0.5382848079983894}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:15,228] Trial 4 finished with value: 0.5225253676685694 and parameters: {'n_estimators': 229, 'max_depth': 10, 'learning_rate': 0.12866998992915288, 'subsample': 0.8572162078882795, 'colsample_bytree': 0.655840913592422, 'gamma': 0.05216557593287502, 'reg_alpha': 0.400533260752406, 'reg_lambda': 1.7683583857098153, 'threshold': 0.6061227863852856, 'adx_th': 24, 'vol_q': 0.85111579409261}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:18,665] Trial 5 finished with value: 1.625688988579847 and parameters: {'n_estimators': 304, 'max_depth': 5, 'learning_rate': 0.05421470653273925, 'subsample': 0.9307559000533763, 'colsample_bytree': 0.9165652018202557, 'gamma': 0.19562167779927592, 'reg_alpha': 0.04478499759156651, 'reg_lambda': 0.785106978167633, 'threshold': 0.5271909663899539, 'adx_th': 16, 'vol_q': 0.5691831314279143}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:21,331] Trial 6 finished with value: 1.271984881392872 and parameters: {'n_estimators': 311, 'max_depth': 10, 'learning_rate': 0.09842706077973358, 'subsample': 0.9758804701712542, 'colsample_bytree': 0.8103548063024423, 'gamma': 0.047012591570862794, 'reg_alpha': 0.08649644988201877, 'reg_lambda': 1.7763802962223605, 'threshold': 0.5258830560787221, 'adx_th': 18, 'vol_q': 0.7881664850842753}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:22,543] Trial 7 finished with value: 1.4660786832411208 and parameters: {'n_estimators': 310, 'max_depth': 7, 'learning_rate': 0.16801823199325172, 'subsample': 0.7804684965228688, 'colsample_bytree': 0.8324670310455032, 'gamma': 0.4010704548816344, 'reg_alpha': 0.4753850366712591, 'reg_lambda': 1.746122620995802, 'threshold': 0.6990097314231253, 'adx_th': 16, 'vol_q': 0.546252015929523}. Best is trial 0 with value: 1.6990022433055447.
# [I 2026-04-24 20:19:24,223] Trial 8 finished with value: 2.2502998029948214 and parameters: {'n_estimators': 158, 'max_depth': 10, 'learning_rate': 0.09582388660223413, 'subsample': 0.939206672459938, 'colsample_bytree': 0.7619540212325769, 'gamma': 0.07642572370455142, 'reg_alpha': 0.4670154625692198, 'reg_lambda': 1.0847291010798694, 'threshold': 0.618590721921111, 'adx_th': 22, 'vol_q': 0.5034193884871803}. Best is trial 8 with value: 2.2502998029948214.
# [I 2026-04-24 20:19:24,884] Trial 9 finished with value: 2.120876032010129 and parameters: {'n_estimators': 290, 'max_depth': 6, 'learning_rate': 0.1705524118531725, 'subsample': 0.9718999893286355, 'colsample_bytree': 0.6181942821518449, 'gamma': 0.43733058077992826, 'reg_alpha': 0.4076708163517763, 'reg_lambda': 1.1144868155088512, 'threshold': 0.5030947224654722, 'adx_th': 12, 'vol_q': 0.5862767988230451}. Best is trial 8 with value: 2.2502998029948214.
# [I 2026-04-24 20:19:26,407] Trial 10 finished with value: 0.8931981992051381 and parameters: {'n_estimators': 189, 'max_depth': 8, 'learning_rate': 0.09840879276642821, 'subsample': 0.6028136672033435, 'colsample_bytree': 0.7308079492981393, 'gamma': 0.011495706585524512, 'reg_alpha': 0.19214522478177232, 'reg_lambda': 1.48367341889658, 'threshold': 0.5895742571934056, 'adx_th': 25, 'vol_q': 0.7291932612496562}. Best is trial 8 with value: 2.2502998029948214.
# [I 2026-04-24 20:19:26,893] Trial 11 finished with value: 4.303119684322745 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.1830492950750599, 'subsample': 0.9995248116747479, 'colsample_bytree': 0.6115586158541289, 'gamma': 0.2954770828509304, 'reg_alpha': 0.4844133258113492, 'reg_lambda': 1.1898318683172096, 'threshold': 0.5473008570673757, 'adx_th': 10, 'vol_q': 0.6329451038884332}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:27,560] Trial 12 finished with value: 2.4877141053201024 and parameters: {'n_estimators': 101, 'max_depth': 7, 'learning_rate': 0.12692396599223835, 'subsample': 0.9993453696551153, 'colsample_bytree': 0.7117944232812526, 'gamma': 0.28639313818990647, 'reg_alpha': 0.48077624120795226, 'reg_lambda': 1.3701915394823643, 'threshold': 0.5753809245021507, 'adx_th': 22, 'vol_q': 0.6737822634655604}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:28,280] Trial 13 finished with value: 3.2179002020245098 and parameters: {'n_estimators': 121, 'max_depth': 7, 'learning_rate': 0.19607744389691306, 'subsample': 0.8713202243942962, 'colsample_bytree': 0.6074288421973117, 'gamma': 0.30153272805819215, 'reg_alpha': 0.3221660150034906, 'reg_lambda': 1.432925262535433, 'threshold': 0.5547678198332165, 'adx_th': 21, 'vol_q': 0.6700816247837418}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:28,747] Trial 14 finished with value: 1.5191524059345731 and parameters: {'n_estimators': 141, 'max_depth': 3, 'learning_rate': 0.18729119743987452, 'subsample': 0.878156218892611, 'colsample_bytree': 0.606030730742135, 'gamma': 0.3371029204962526, 'reg_alpha': 0.32631257209424314, 'reg_lambda': 1.522486110846109, 'threshold': 0.5526797726927895, 'adx_th': 13, 'vol_q': 0.6355710235094921}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:31,097] Trial 15 finished with value: 1.4480892103909853 and parameters: {'n_estimators': 203, 'max_depth': 6, 'learning_rate': 0.1990948377972013, 'subsample': 0.7797529238054638, 'colsample_bytree': 0.6724292405213901, 'gamma': 0.47971698906590515, 'reg_alpha': 0.14287080129462232, 'reg_lambda': 0.9198711408264761, 'threshold': 0.5498138459190205, 'adx_th': 20, 'vol_q': 0.7429623773326723}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:32,314] Trial 16 finished with value: 1.613485615152646 and parameters: {'n_estimators': 133, 'max_depth': 8, 'learning_rate': 0.15082893661470015, 'subsample': 0.8843087237299538, 'colsample_bytree': 0.8589488149897935, 'gamma': 0.1955680253483504, 'reg_alpha': 0.3275542535487332, 'reg_lambda': 0.5192274990962784, 'threshold': 0.49753558838583695, 'adx_th': 10, 'vol_q': 0.7867561819537023}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:33,156] Trial 17 finished with value: 1.3032776510776978 and parameters: {'n_estimators': 184, 'max_depth': 5, 'learning_rate': 0.14889724135580118, 'subsample': 0.7419358669790488, 'colsample_bytree': 0.6065604733366815, 'gamma': 0.3185609639880252, 'reg_alpha': 0.28204385492020145, 'reg_lambda': 1.347216988644542, 'threshold': 0.5548650311351213, 'adx_th': 19, 'vol_q': 0.7027115930777759}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:34,534] Trial 18 finished with value: 1.843647295420995 and parameters: {'n_estimators': 382, 'max_depth': 8, 'learning_rate': 0.17957073511378877, 'subsample': 0.8140473228264125, 'colsample_bytree': 0.696862720863361, 'gamma': 0.21008816396830793, 'reg_alpha': 0.3710478860891536, 'reg_lambda': 1.5758491668182701, 'threshold': 0.5074523154347765, 'adx_th': 13, 'vol_q': 0.6225596733199199}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:35,318] Trial 19 finished with value: 0.9117825492527295 and parameters: {'n_estimators': 120, 'max_depth': 6, 'learning_rate': 0.19966141828289896, 'subsample': 0.9016465576384116, 'colsample_bytree': 0.643519163938866, 'gamma': 0.13501202326641065, 'reg_alpha': 0.15584343769844672, 'reg_lambda': 1.2472227511318703, 'threshold': 0.6440156897044055, 'adx_th': 23, 'vol_q': 0.6859609805374743}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:36,639] Trial 20 finished with value: 0.7815859757459352 and parameters: {'n_estimators': 224, 'max_depth': 7, 'learning_rate': 0.15017527831092206, 'subsample': 0.6868397012502152, 'colsample_bytree': 0.7387734683223257, 'gamma': 0.24229080557831312, 'reg_alpha': 0.49549949964599466, 'reg_lambda': 1.2366381156981776, 'threshold': 0.5820039914118843, 'adx_th': 20, 'vol_q': 0.7601566171068392}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:37,421] Trial 21 finished with value: 3.2305223729963823 and parameters: {'n_estimators': 112, 'max_depth': 7, 'learning_rate': 0.1187998330075035, 'subsample': 0.9777837948697052, 'colsample_bytree': 0.7069873323984653, 'gamma': 0.2925324306520807, 'reg_alpha': 0.4430521515287591, 'reg_lambda': 1.3932861748608438, 'threshold': 0.5682572714786247, 'adx_th': 22, 'vol_q': 0.6628855384335173}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:38,089] Trial 22 finished with value: 1.5535690746515913 and parameters: {'n_estimators': 101, 'max_depth': 7, 'learning_rate': 0.12485180965039971, 'subsample': 0.994940088345442, 'colsample_bytree': 0.6837913147517245, 'gamma': 0.30858120716408216, 'reg_alpha': 0.43536496614463593, 'reg_lambda': 1.5938178356665587, 'threshold': 0.541844020096075, 'adx_th': 23, 'vol_q': 0.6358732633589742}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:39,159] Trial 23 finished with value: 1.0201511259093852 and parameters: {'n_estimators': 163, 'max_depth': 8, 'learning_rate': 0.07908768948635514, 'subsample': 0.9480689055171597, 'colsample_bytree': 0.6400751723840513, 'gamma': 0.3540755597603235, 'reg_alpha': 0.3715207470261217, 'reg_lambda': 1.4088834284702842, 'threshold': 0.6005483866236855, 'adx_th': 21, 'vol_q': 0.7021504290900993}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:39,855] Trial 24 finished with value: 0.9792303771103942 and parameters: {'n_estimators': 133, 'max_depth': 6, 'learning_rate': 0.16277149090741352, 'subsample': 0.9599221851723466, 'colsample_bytree': 0.601000464278902, 'gamma': 0.244730678919749, 'reg_alpha': 0.43913315602612607, 'reg_lambda': 1.16173172726447, 'threshold': 0.5683699078642238, 'adx_th': 25, 'vol_q': 0.8962027662438944}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:40,697] Trial 25 finished with value: 1.8054030401586403 and parameters: {'n_estimators': 170, 'max_depth': 9, 'learning_rate': 0.18258570927981843, 'subsample': 0.9094276816156247, 'colsample_bytree': 0.6355107180134212, 'gamma': 0.2877945785170932, 'reg_alpha': 0.3052700678842672, 'reg_lambda': 1.2868736796111648, 'threshold': 0.5264611815740073, 'adx_th': 17, 'vol_q': 0.6102031376884469}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:41,289] Trial 26 finished with value: 1.9758412216986858 and parameters: {'n_estimators': 129, 'max_depth': 4, 'learning_rate': 0.11660962261329905, 'subsample': 0.8490367312922186, 'colsample_bytree': 0.7103791869074896, 'gamma': 0.44461546686544007, 'reg_alpha': 0.36741918843918414, 'reg_lambda': 0.955895750210332, 'threshold': 0.48612376402692825, 'adx_th': 19, 'vol_q': 0.6504533283694047}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:43,951] Trial 27 finished with value: 1.5840146486515119 and parameters: {'n_estimators': 149, 'max_depth': 7, 'learning_rate': 0.1408061731616711, 'subsample': 0.9983393011107582, 'colsample_bytree': 0.7700852125517169, 'gamma': 0.15234319217356673, 'reg_alpha': 0.49534846292829826, 'reg_lambda': 1.6511233514527686, 'threshold': 0.6214715190487501, 'adx_th': 14, 'vol_q': 0.6725352000610516}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:44,761] Trial 28 finished with value: 1.4298861793152637 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.1890626372197854, 'subsample': 0.8750576579912178, 'colsample_bytree': 0.6837463620814499, 'gamma': 0.22089153652351584, 'reg_alpha': 0.4481706958062356, 'reg_lambda': 1.453531728218859, 'threshold': 0.5627406272413654, 'adx_th': 23, 'vol_q': 0.7260871534397996}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:45,853] Trial 29 finished with value: 1.3505620018934812 and parameters: {'n_estimators': 201, 'max_depth': 5, 'learning_rate': 0.08147476561478836, 'subsample': 0.9546162150413764, 'colsample_bytree': 0.9875797625471091, 'gamma': 0.3983542921155694, 'reg_alpha': 0.22691775438861023, 'reg_lambda': 0.9762908243165082, 'threshold': 0.5347725005738977, 'adx_th': 19, 'vol_q': 0.6556105724596534}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:46,869] Trial 30 finished with value: 1.8716750403774631 and parameters: {'n_estimators': 266, 'max_depth': 6, 'learning_rate': 0.15931343504651754, 'subsample': 0.8164820713314828, 'colsample_bytree': 0.6338126380553588, 'gamma': 0.3259332831704121, 'reg_alpha': 0.28266738950185993, 'reg_lambda': 1.1832725684443464, 'threshold': 0.5148285040473013, 'adx_th': 11, 'vol_q': 0.5759855466036092}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:47,604] Trial 31 finished with value: 1.750851970414855 and parameters: {'n_estimators': 115, 'max_depth': 7, 'learning_rate': 0.12957662445160148, 'subsample': 0.988251060572802, 'colsample_bytree': 0.7191032722340642, 'gamma': 0.2857764102619702, 'reg_alpha': 0.4595383691052797, 'reg_lambda': 1.3652772770366428, 'threshold': 0.5761768638337171, 'adx_th': 22, 'vol_q': 0.6716126309646113}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:48,568] Trial 32 finished with value: 1.3275677773713699 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.1169166822095155, 'subsample': 0.9128046551638415, 'colsample_bytree': 0.7442139307800817, 'gamma': 0.2693082506367506, 'reg_alpha': 0.4989721079359948, 'reg_lambda': 1.3474909004495412, 'threshold': 0.5870831429677128, 'adx_th': 21, 'vol_q': 0.7079080425073349}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:49,498] Trial 33 finished with value: 1.3434098574094284 and parameters: {'n_estimators': 120, 'max_depth': 7, 'learning_rate': 0.08125521843432566, 'subsample': 0.9648971485738561, 'colsample_bytree': 0.6635797235725783, 'gamma': 0.2943790752292648, 'reg_alpha': 0.4178115916746412, 'reg_lambda': 1.650613848119169, 'threshold': 0.5687383342909292, 'adx_th': 22, 'vol_q': 0.6737358646201375}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:50,331] Trial 34 finished with value: 2.0383812350706716 and parameters: {'n_estimators': 345, 'max_depth': 6, 'learning_rate': 0.13927841456410053, 'subsample': 0.9971649620064962, 'colsample_bytree': 0.8696446420537037, 'gamma': 0.3700714517591658, 'reg_alpha': 0.3833551925582394, 'reg_lambda': 1.2793506994103965, 'threshold': 0.6030832551458211, 'adx_th': 24, 'vol_q': 0.6016785498961595}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:51,382] Trial 35 finished with value: 3.6173970514139153 and parameters: {'n_estimators': 145, 'max_depth': 7, 'learning_rate': 0.11232667395699897, 'subsample': 0.9459918958892526, 'colsample_bytree': 0.8005478252217209, 'gamma': 0.2610903773659367, 'reg_alpha': 0.4368982252156334, 'reg_lambda': 1.428379788953072, 'threshold': 0.6443041709711335, 'adx_th': 20, 'vol_q': 0.6442314582880848}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:53,271] Trial 36 finished with value: 1.1646772915222152 and parameters: {'n_estimators': 144, 'max_depth': 9, 'learning_rate': 0.03664691102812065, 'subsample': 0.931509873964659, 'colsample_bytree': 0.7983460178857488, 'gamma': 0.25149146667598626, 'reg_alpha': 0.42549032414899407, 'reg_lambda': 1.4814961998459104, 'threshold': 0.6506780137256999, 'adx_th': 20, 'vol_q': 0.635688485753549}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:55,570] Trial 37 finished with value: 1.7288495488229563 and parameters: {'n_estimators': 175, 'max_depth': 5, 'learning_rate': 0.07067300541015746, 'subsample': 0.8991604256834512, 'colsample_bytree': 0.8070412211070114, 'gamma': 0.16489550584600238, 'reg_alpha': 0.34368183451430867, 'reg_lambda': 1.016503247655872, 'threshold': 0.6805725896377203, 'adx_th': 18, 'vol_q': 0.5506921841024076}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:56,655] Trial 38 finished with value: 1.9094653137155895 and parameters: {'n_estimators': 122, 'max_depth': 4, 'learning_rate': 0.11280599742030425, 'subsample': 0.8516992958653484, 'colsample_bytree': 0.8938910575089811, 'gamma': 0.35237247088460966, 'reg_alpha': 0.3958585401375527, 'reg_lambda': 0.8518461196290653, 'threshold': 0.6615234484350999, 'adx_th': 17, 'vol_q': 0.6121249566794741}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:19:57,750] Trial 39 finished with value: 3.9262116758401446 and parameters: {'n_estimators': 231, 'max_depth': 8, 'learning_rate': 0.1738572287186053, 'subsample': 0.9444108321364164, 'colsample_bytree': 0.8439343485679125, 'gamma': 0.2268472007679403, 'reg_alpha': 0.26294716788849487, 'reg_lambda': 1.8771640952459847, 'threshold': 0.625584936440016, 'adx_th': 16, 'vol_q': 0.6503053649861736}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:00,519] Trial 40 finished with value: 2.1182296539835668 and parameters: {'n_estimators': 237, 'max_depth': 8, 'learning_rate': 0.01786511988449352, 'subsample': 0.9302472437027112, 'colsample_bytree': 0.8471376029616846, 'gamma': 0.12039125693751299, 'reg_alpha': 0.03883893822149878, 'reg_lambda': 1.9754118632329878, 'threshold': 0.6197487316838535, 'adx_th': 15, 'vol_q': 0.587804233744446}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:01,547] Trial 41 finished with value: 0.9214955669530566 and parameters: {'n_estimators': 275, 'max_depth': 7, 'learning_rate': 0.17538000927148123, 'subsample': 0.9674419573897742, 'colsample_bytree': 0.826105925162965, 'gamma': 0.2296611585487163, 'reg_alpha': 0.22786981173661586, 'reg_lambda': 1.8042158189321693, 'threshold': 0.6307716392816198, 'adx_th': 21, 'vol_q': 0.6495522746690585}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:02,385] Trial 42 finished with value: 1.5401952875637226 and parameters: {'n_estimators': 157, 'max_depth': 9, 'learning_rate': 0.19129620406210676, 'subsample': 0.9500737991756651, 'colsample_bytree': 0.7875705322662692, 'gamma': 0.2682137358261714, 'reg_alpha': 0.27182277444975694, 'reg_lambda': 1.7084702427866207, 'threshold': 0.6673746397213302, 'adx_th': 10, 'vol_q': 0.6221354541620348}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:04,293] Trial 43 finished with value: 2.2901077330147768 and parameters: {'n_estimators': 338, 'max_depth': 8, 'learning_rate': 0.17108402296545142, 'subsample': 0.9806431990984052, 'colsample_bytree': 0.9011822281796067, 'gamma': 0.17111553734745755, 'reg_alpha': 0.2463756439676133, 'reg_lambda': 1.9838912935541604, 'threshold': 0.5408420350200459, 'adx_th': 15, 'vol_q': 0.6829818044131759}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:05,476] Trial 44 finished with value: 1.4127277652278931 and parameters: {'n_estimators': 247, 'max_depth': 6, 'learning_rate': 0.1588959921560148, 'subsample': 0.929273580325737, 'colsample_bytree': 0.7510976077396263, 'gamma': 0.20208808987244814, 'reg_alpha': 0.19624726789535607, 'reg_lambda': 1.862254836002696, 'threshold': 0.633175986914156, 'adx_th': 18, 'vol_q': 0.7177187931047567}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:07,306] Trial 45 finished with value: 1.7452547306855883 and parameters: {'n_estimators': 145, 'max_depth': 7, 'learning_rate': 0.09285986814081579, 'subsample': 0.969319136840413, 'colsample_bytree': 0.94066978749084, 'gamma': 0.25962417786917746, 'reg_alpha': 0.4661530695172453, 'reg_lambda': 1.1060292675938659, 'threshold': 0.6909323638033658, 'adx_th': 16, 'vol_q': 0.55951368143125}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:09,632] Trial 46 finished with value: 3.4090117549381596 and parameters: {'n_estimators': 215, 'max_depth': 8, 'learning_rate': 0.11004419196914607, 'subsample': 0.8901974729462843, 'colsample_bytree': 0.8252242437417235, 'gamma': 0.3074688333131286, 'reg_alpha': 0.3986230454410731, 'reg_lambda': 1.4276231631380008, 'threshold': 0.5945547358562409, 'adx_th': 12, 'vol_q': 0.6600121220862635}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:10,671] Trial 47 finished with value: 1.826752891048656 and parameters: {'n_estimators': 219, 'max_depth': 8, 'learning_rate': 0.10908327918550714, 'subsample': 0.9394750220912553, 'colsample_bytree': 0.8426987763163053, 'gamma': 0.3769012604498728, 'reg_alpha': 0.4024045429153982, 'reg_lambda': 0.7300456163709445, 'threshold': 0.5952061622174157, 'adx_th': 11, 'vol_q': 0.6446950171175445}. Best is trial 11 with value: 4.303119684322745.
# [I 2026-04-24 20:20:12,229] Trial 48 finished with value: 4.5106007462911055 and parameters: {'n_estimators': 205, 'max_depth': 9, 'learning_rate': 0.10491732437930464, 'subsample': 0.9186154162693753, 'colsample_bytree': 0.8219438928672915, 'gamma': 0.18505075345574, 'reg_alpha': 0.35271069726115295, 'reg_lambda': 1.5294452330635206, 'threshold': 0.6128886279754717, 'adx_th': 12, 'vol_q': 0.5886814097930789}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:14,156] Trial 49 finished with value: 2.3781647020275014 and parameters: {'n_estimators': 203, 'max_depth': 10, 'learning_rate': 0.1049817958446041, 'subsample': 0.8918563035083457, 'colsample_bytree': 0.8231033757480096, 'gamma': 0.11050292157756683, 'reg_alpha': 0.35699498649677613, 'reg_lambda': 1.579821143982734, 'threshold': 0.6103635347902066, 'adx_th': 12, 'vol_q': 0.5853641441791628}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:16,377] Trial 50 finished with value: 3.5413007952356295 and parameters: {'n_estimators': 213, 'max_depth': 9, 'learning_rate': 0.06577536877553286, 'subsample': 0.8630624672613466, 'colsample_bytree': 0.8856502996623343, 'gamma': 0.18041146559819402, 'reg_alpha': 0.08495064175165626, 'reg_lambda': 1.5113225851488834, 'threshold': 0.6351299318803787, 'adx_th': 13, 'vol_q': 0.6229555625480692}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:18,647] Trial 51 finished with value: 4.182704974205723 and parameters: {'n_estimators': 215, 'max_depth': 9, 'learning_rate': 0.058972514087035265, 'subsample': 0.9172355191793944, 'colsample_bytree': 0.8782903666704386, 'gamma': 0.18700754653703938, 'reg_alpha': 0.06888609980398584, 'reg_lambda': 1.661382969299071, 'threshold': 0.6505083113854299, 'adx_th': 13, 'vol_q': 0.6200252582624859}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:22,631] Trial 52 finished with value: 3.763629416015686 and parameters: {'n_estimators': 239, 'max_depth': 9, 'learning_rate': 0.06531697752098885, 'subsample': 0.9156317481336695, 'colsample_bytree': 0.8742356461887438, 'gamma': 0.19157071434812162, 'reg_alpha': 0.07781310728794075, 'reg_lambda': 1.519592605223373, 'threshold': 0.6562651209972951, 'adx_th': 13, 'vol_q': 0.5194720183869828}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:25,478] Trial 53 finished with value: 3.6592419513604146 and parameters: {'n_estimators': 244, 'max_depth': 10, 'learning_rate': 0.048766498897663935, 'subsample': 0.9184349058628613, 'colsample_bytree': 0.9362438872106779, 'gamma': 0.1908196060850784, 'reg_alpha': 0.00899510079350907, 'reg_lambda': 1.6770605739933673, 'threshold': 0.6534802905552581, 'adx_th': 14, 'vol_q': 0.5269385116221694}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:28,444] Trial 54 finished with value: 3.576025714400116 and parameters: {'n_estimators': 241, 'max_depth': 10, 'learning_rate': 0.04992749139729941, 'subsample': 0.9090352878531951, 'colsample_bytree': 0.9355583461730472, 'gamma': 0.0814190185755461, 'reg_alpha': 0.0028194778262792125, 'reg_lambda': 1.716234725004998, 'threshold': 0.6569059626946446, 'adx_th': 14, 'vol_q': 0.5300006158495358}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:31,399] Trial 55 finished with value: 2.927220796358778 and parameters: {'n_estimators': 283, 'max_depth': 10, 'learning_rate': 0.05833239372255705, 'subsample': 0.9167885508210131, 'colsample_bytree': 0.9536401983185477, 'gamma': 0.18404243267062223, 'reg_alpha': 0.09526821604050048, 'reg_lambda': 1.837474464922034, 'threshold': 0.6783082430661872, 'adx_th': 14, 'vol_q': 0.5040823662675513}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:36,103] Trial 56 finished with value: 1.8289973028290503 and parameters: {'n_estimators': 256, 'max_depth': 9, 'learning_rate': 0.04002826516720345, 'subsample': 0.8402625364047334, 'colsample_bytree': 0.9194667306436184, 'gamma': 0.22559859492967227, 'reg_alpha': 0.0028036237357095557, 'reg_lambda': 1.6795943035352034, 'threshold': 0.6659066309933046, 'adx_th': 11, 'vol_q': 0.5216562411893262}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:39,824] Trial 57 finished with value: 2.913774697067741 and parameters: {'n_estimators': 303, 'max_depth': 10, 'learning_rate': 0.011754435944039007, 'subsample': 0.6260594647541817, 'colsample_bytree': 0.8696385415479962, 'gamma': 0.1389208199458068, 'reg_alpha': 0.05704884044495358, 'reg_lambda': 1.7699842036535913, 'threshold': 0.6520363209940516, 'adx_th': 12, 'vol_q': 0.5395152883847448}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:42,414] Trial 58 finished with value: 2.022992706170535 and parameters: {'n_estimators': 262, 'max_depth': 9, 'learning_rate': 0.06572054414309338, 'subsample': 0.7730563358245987, 'colsample_bytree': 0.9189837499005075, 'gamma': 0.19207879649657156, 'reg_alpha': 0.12801420949774117, 'reg_lambda': 1.5452258607342813, 'threshold': 0.6114977263783095, 'adx_th': 13, 'vol_q': 0.5623871946832274}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:46,718] Trial 59 finished with value: 2.117393246309548 and parameters: {'n_estimators': 188, 'max_depth': 10, 'learning_rate': 0.02635978802407537, 'subsample': 0.9204743445295971, 'colsample_bytree': 0.8718348378400775, 'gamma': 0.20581244014581862, 'reg_alpha': 0.04688626865914783, 'reg_lambda': 1.6227924356705201, 'threshold': 0.45181376847079163, 'adx_th': 10, 'vol_q': 0.5026812449142827}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:49,704] Trial 60 finished with value: 2.4226042463035986 and parameters: {'n_estimators': 233, 'max_depth': 9, 'learning_rate': 0.044188427087827525, 'subsample': 0.8634235476800038, 'colsample_bytree': 0.9809143759199589, 'gamma': 0.15843562575367895, 'reg_alpha': 0.02588264876771068, 'reg_lambda': 1.8144183280703974, 'threshold': 0.6888924783149433, 'adx_th': 14, 'vol_q': 0.5251539288051009}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:52,705] Trial 61 finished with value: 1.7206207227482195 and parameters: {'n_estimators': 248, 'max_depth': 9, 'learning_rate': 0.02838660507249634, 'subsample': 0.939262207621707, 'colsample_bytree': 0.8479896243232611, 'gamma': 0.23215492436599489, 'reg_alpha': 0.07007456213747885, 'reg_lambda': 1.9338143554854097, 'threshold': 0.64362920497624, 'adx_th': 13, 'vol_q': 0.5970907371157519}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:54,259] Trial 62 finished with value: 2.07652205633583 and parameters: {'n_estimators': 195, 'max_depth': 9, 'learning_rate': 0.08972536468341573, 'subsample': 0.9537276687224274, 'colsample_bytree': 0.8128850222368763, 'gamma': 0.21548695926001785, 'reg_alpha': 0.11282943143139088, 'reg_lambda': 1.5432496518762444, 'threshold': 0.6268376173569994, 'adx_th': 11, 'vol_q': 0.5728121787592858}. Best is trial 48 with value: 4.5106007462911055.
# [I 2026-04-24 20:20:56,508] Trial 63 finished with value: 5.072421423887901 and parameters: {'n_estimators': 228, 'max_depth': 10, 'learning_rate': 0.05553816864991287, 'subsample': 0.8813729066437143, 'colsample_bytree': 0.7844641899773604, 'gamma': 0.24131935759481857, 'reg_alpha': 0.16744938924176078, 'reg_lambda': 1.9090558784360103, 'threshold': 0.6416710235062494, 'adx_th': 16, 'vol_q': 0.623591023137005}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:01,104] Trial 64 finished with value: 4.372253592474211 and parameters: {'n_estimators': 226, 'max_depth': 10, 'learning_rate': 0.05892275888545757, 'subsample': 0.877384112868211, 'colsample_bytree': 0.903465550043578, 'gamma': 0.10095252359506107, 'reg_alpha': 0.16716773075110966, 'reg_lambda': 1.9176462293926302, 'threshold': 0.6398570661079429, 'adx_th': 16, 'vol_q': 0.6204570834240715}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:03,772] Trial 65 finished with value: 4.232759734388612 and parameters: {'n_estimators': 227, 'max_depth': 10, 'learning_rate': 0.07343412975171591, 'subsample': 0.8277362692026466, 'colsample_bytree': 0.9054999704999823, 'gamma': 0.0738712473201026, 'reg_alpha': 0.16543108192822298, 'reg_lambda': 1.9007207057639386, 'threshold': 0.6153716458454589, 'adx_th': 15, 'vol_q': 0.622116593779647}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:06,642] Trial 66 finished with value: 2.2890134806216644 and parameters: {'n_estimators': 226, 'max_depth': 10, 'learning_rate': 0.05606012225326363, 'subsample': 0.8283476246912069, 'colsample_bytree': 0.8547473498757092, 'gamma': 0.0046527370904122095, 'reg_alpha': 0.17643287664286528, 'reg_lambda': 1.9049468402723926, 'threshold': 0.6113486654523017, 'adx_th': 16, 'vol_q': 0.6244984591983601}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:09,204] Trial 67 finished with value: 2.3990845637355966 and parameters: {'n_estimators': 213, 'max_depth': 10, 'learning_rate': 0.07731014090426758, 'subsample': 0.7963855315828493, 'colsample_bytree': 0.8974785985912449, 'gamma': 0.030667138558549523, 'reg_alpha': 0.20054244101442514, 'reg_lambda': 1.9216925044872128, 'threshold': 0.6372343583650022, 'adx_th': 17, 'vol_q': 0.6091592293759753}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:13,602] Trial 68 finished with value: 3.082897129653998 and parameters: {'n_estimators': 228, 'max_depth': 10, 'learning_rate': 0.08834092244969026, 'subsample': 0.881177762252538, 'colsample_bytree': 0.9083539737942645, 'gamma': 0.08943549689835315, 'reg_alpha': 0.16423234557431407, 'reg_lambda': 1.880979138601641, 'threshold': 0.6245747104051605, 'adx_th': 15, 'vol_q': 0.599773549338669}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:15,832] Trial 69 finished with value: 1.0555892496016985 and parameters: {'n_estimators': 180, 'max_depth': 10, 'learning_rate': 0.06225139408332953, 'subsample': 0.7575084552526221, 'colsample_bytree': 0.8839203286324082, 'gamma': 0.0610634067397795, 'reg_alpha': 0.21003516142130718, 'reg_lambda': 1.7392483569971258, 'threshold': 0.6160728620879177, 'adx_th': 16, 'vol_q': 0.6861011083848045}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:18,133] Trial 70 finished with value: 2.948802449532529 and parameters: {'n_estimators': 203, 'max_depth': 10, 'learning_rate': 0.07294823523533654, 'subsample': 0.8281863009551623, 'colsample_bytree': 0.8400328981811092, 'gamma': 0.10638491223379035, 'reg_alpha': 0.1417514358303778, 'reg_lambda': 1.9962188883100305, 'threshold': 0.6415310466738008, 'adx_th': 17, 'vol_q': 0.6332134898456715}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:21,046] Trial 71 finished with value: 3.7765671549260715 and parameters: {'n_estimators': 271, 'max_depth': 9, 'learning_rate': 0.05052348362023325, 'subsample': 0.9002049704611104, 'colsample_bytree': 0.8626483525778579, 'gamma': 0.1293650857707223, 'reg_alpha': 0.11089135519298973, 'reg_lambda': 1.9397483644720663, 'threshold': 0.6735135052751501, 'adx_th': 15, 'vol_q': 0.5824567381729269}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:25,781] Trial 72 finished with value: 4.120930816289646 and parameters: {'n_estimators': 271, 'max_depth': 9, 'learning_rate': 0.05108858197558189, 'subsample': 0.896122839216498, 'colsample_bytree': 0.8625819533282498, 'gamma': 0.06761093199879523, 'reg_alpha': 0.10110499764633878, 'reg_lambda': 1.9301393520550385, 'threshold': 0.6769247447087531, 'adx_th': 15, 'vol_q': 0.584559682219601}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:28,382] Trial 73 finished with value: 2.934126633310738 and parameters: {'n_estimators': 253, 'max_depth': 9, 'learning_rate': 0.05509360686058878, 'subsample': 0.8767435163852092, 'colsample_bytree': 0.787002785807093, 'gamma': 0.0316593562613918, 'reg_alpha': 0.1750075296639852, 'reg_lambda': 1.8448753847271318, 'threshold': 0.6270805216970987, 'adx_th': 16, 'vol_q': 0.6157129226138269}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:32,421] Trial 74 finished with value: 3.9379655297379657 and parameters: {'n_estimators': 289, 'max_depth': 10, 'learning_rate': 0.030718954211840857, 'subsample': 0.8414562007380705, 'colsample_bytree': 0.9581923674046745, 'gamma': 0.06643663882213703, 'reg_alpha': 0.1466247742093616, 'reg_lambda': 1.8073186969326525, 'threshold': 0.6486769955314939, 'adx_th': 16, 'vol_q': 0.5911104664482886}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:38,177] Trial 75 finished with value: 1.8038496260995973 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.029873167823505832, 'subsample': 0.8005383274928533, 'colsample_bytree': 0.9474628898773506, 'gamma': 0.0606850095777848, 'reg_alpha': 0.1325876215647236, 'reg_lambda': 1.952228217932418, 'threshold': 0.6489452432375457, 'adx_th': 15, 'vol_q': 0.5989595118129377}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:42,174] Trial 76 finished with value: 2.3765959277289728 and parameters: {'n_estimators': 323, 'max_depth': 10, 'learning_rate': 0.04152708853961551, 'subsample': 0.8432457636465113, 'colsample_bytree': 0.9685562663409718, 'gamma': 0.09485840108947095, 'reg_alpha': 0.10084743495044551, 'reg_lambda': 1.8159126454567283, 'threshold': 0.6672635280725161, 'adx_th': 17, 'vol_q': 0.5512922847139361}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:46,271] Trial 77 finished with value: 1.504545340256566 and parameters: {'n_estimators': 299, 'max_depth': 10, 'learning_rate': 0.021935486930484985, 'subsample': 0.8592934270121761, 'colsample_bytree': 0.8863658005520321, 'gamma': 0.045035518144999946, 'reg_alpha': 0.1562436951710195, 'reg_lambda': 1.774023104582903, 'threshold': 0.6979541568599072, 'adx_th': 15, 'vol_q': 0.5634821058613204}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:49,728] Trial 78 finished with value: 1.1136502324526634 and parameters: {'n_estimators': 282, 'max_depth': 5, 'learning_rate': 0.061194407984019775, 'subsample': 0.8173255796389511, 'colsample_bytree': 0.9963195078560225, 'gamma': 0.07199144547317202, 'reg_alpha': 0.18322998822184966, 'reg_lambda': 1.8860080202498963, 'threshold': 0.6610547317495988, 'adx_th': 16, 'vol_q': 0.5956039633744209}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:53,628] Trial 79 finished with value: 1.0194052266365463 and parameters: {'n_estimators': 312, 'max_depth': 9, 'learning_rate': 0.034033745152840675, 'subsample': 0.8712855941097472, 'colsample_bytree': 0.959720898905227, 'gamma': 0.02150200216640416, 'reg_alpha': 0.12098705835493903, 'reg_lambda': 1.7412806057049255, 'threshold': 0.5178817405751173, 'adx_th': 14, 'vol_q': 0.8388374334326918}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:57,151] Trial 80 finished with value: 2.216548276630951 and parameters: {'n_estimators': 384, 'max_depth': 10, 'learning_rate': 0.07297777282925043, 'subsample': 0.8929934894412167, 'colsample_bytree': 0.9083911156222965, 'gamma': 0.04554449202613786, 'reg_alpha': 0.21841381501621082, 'reg_lambda': 1.1926740880487903, 'threshold': 0.6727189740253521, 'adx_th': 15, 'vol_q': 0.6321066081135694}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:21:59,247] Trial 81 finished with value: 1.8008562254652773 and parameters: {'n_estimators': 223, 'max_depth': 9, 'learning_rate': 0.10138418029270199, 'subsample': 0.8709453877703894, 'colsample_bytree': 0.9274584572194362, 'gamma': 0.14181514690028052, 'reg_alpha': 0.15375931982211766, 'reg_lambda': 1.8696400696224358, 'threshold': 0.6413497741634461, 'adx_th': 16, 'vol_q': 0.6101971173144969}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:02,991] Trial 82 finished with value: 2.2295939861452685 and parameters: {'n_estimators': 207, 'max_depth': 8, 'learning_rate': 0.08457985933987038, 'subsample': 0.8516957654419967, 'colsample_bytree': 0.8351140118012279, 'gamma': 0.06997817205385815, 'reg_alpha': 0.3102254797170767, 'reg_lambda': 1.7996842201106449, 'threshold': 0.6169529548371422, 'adx_th': 17, 'vol_q': 0.5894245953738108}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:05,424] Trial 83 finished with value: 2.018300682296195 and parameters: {'n_estimators': 233, 'max_depth': 10, 'learning_rate': 0.05331176156037123, 'subsample': 0.689670060498502, 'colsample_bytree': 0.8773733879751822, 'gamma': 0.09567049081085219, 'reg_alpha': 0.24734413912221834, 'reg_lambda': 0.5204084899180117, 'threshold': 0.6304474639138916, 'adx_th': 16, 'vol_q': 0.5742713970668056}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:06,964] Trial 84 finished with value: 1.8888907164172233 and parameters: {'n_estimators': 264, 'max_depth': 9, 'learning_rate': 0.1934051798090436, 'subsample': 0.9047079857259612, 'colsample_bytree': 0.860078241302107, 'gamma': 0.11565113483689804, 'reg_alpha': 0.14142375992099745, 'reg_lambda': 1.9605624337446916, 'threshold': 0.6482523515112661, 'adx_th': 10, 'vol_q': 0.6434343776296226}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:09,319] Trial 85 finished with value: 3.869089610436895 and parameters: {'n_estimators': 195, 'max_depth': 9, 'learning_rate': 0.03427628540479667, 'subsample': 0.8873211459857776, 'colsample_bytree': 0.8528669277612948, 'gamma': 0.2788819297423926, 'reg_alpha': 0.06560785363437185, 'reg_lambda': 1.8984827426660076, 'threshold': 0.6048684840245112, 'adx_th': 15, 'vol_q': 0.6262304989758227}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:10,525] Trial 86 finished with value: 1.9602436099662703 and parameters: {'n_estimators': 372, 'max_depth': 10, 'learning_rate': 0.18528356567528736, 'subsample': 0.8348855457698892, 'colsample_bytree': 0.6177217817958278, 'gamma': 0.24797288579581306, 'reg_alpha': 0.2595007172805063, 'reg_lambda': 1.920692650240197, 'threshold': 0.6383213356843865, 'adx_th': 14, 'vol_q': 0.6583138372155091}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:11,936] Trial 87 finished with value: 2.1264055892001004 and parameters: {'n_estimators': 167, 'max_depth': 6, 'learning_rate': 0.04695093799127529, 'subsample': 0.8965402931080193, 'colsample_bytree': 0.9088847140852206, 'gamma': 0.3295055995982779, 'reg_alpha': 0.2945726181273927, 'reg_lambda': 1.8371435354982313, 'threshold': 0.5885463671730262, 'adx_th': 18, 'vol_q': 0.6145330290506461}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:14,779] Trial 88 finished with value: 3.2616886441322404 and parameters: {'n_estimators': 220, 'max_depth': 8, 'learning_rate': 0.17920398114313546, 'subsample': 0.9333301940292231, 'colsample_bytree': 0.8135262784609335, 'gamma': 0.2388156353998542, 'reg_alpha': 0.09603183810747468, 'reg_lambda': 1.711569513727733, 'threshold': 0.6819702829425854, 'adx_th': 17, 'vol_q': 0.6052634136809731}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:17,502] Trial 89 finished with value: 1.4335002166741837 and parameters: {'n_estimators': 255, 'max_depth': 9, 'learning_rate': 0.03948333010227346, 'subsample': 0.987320097207203, 'colsample_bytree': 0.7704156919412711, 'gamma': 0.05530411387675151, 'reg_alpha': 0.16631360499506306, 'reg_lambda': 1.6248395519390333, 'threshold': 0.5805474338566936, 'adx_th': 12, 'vol_q': 0.640432693014438}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:19,049] Trial 90 finished with value: 1.9675265735554772 and parameters: {'n_estimators': 210, 'max_depth': 10, 'learning_rate': 0.13905791952714436, 'subsample': 0.8066640985330356, 'colsample_bytree': 0.8917860224056942, 'gamma': 0.1771138637427699, 'reg_alpha': 0.18835916311289969, 'reg_lambda': 1.3044756484294604, 'threshold': 0.5595655232436056, 'adx_th': 11, 'vol_q': 0.5776102793625594}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:22,205] Trial 91 finished with value: 4.279951914082933 and parameters: {'n_estimators': 295, 'max_depth': 9, 'learning_rate': 0.03351672517082994, 'subsample': 0.8842420041826644, 'colsample_bytree': 0.8492861521587123, 'gamma': 0.277189120327164, 'reg_alpha': 0.06945669262595422, 'reg_lambda': 1.8532990904983793, 'threshold': 0.6026709948713572, 'adx_th': 15, 'vol_q': 0.6227157928989263}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:26,055] Trial 92 finished with value: 4.891232556128297 and parameters: {'n_estimators': 297, 'max_depth': 8, 'learning_rate': 0.04496801276062187, 'subsample': 0.8847368032854818, 'colsample_bytree': 0.8297874297971455, 'gamma': 0.2718825065245833, 'reg_alpha': 0.11135989511112782, 'reg_lambda': 1.9897144166245027, 'threshold': 0.5955968429704228, 'adx_th': 16, 'vol_q': 0.6171827016497878}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:29,137] Trial 93 finished with value: 4.429921326661765 and parameters: {'n_estimators': 292, 'max_depth': 9, 'learning_rate': 0.04596255437790813, 'subsample': 0.8850193829627905, 'colsample_bytree': 0.8306797263875692, 'gamma': 0.27518838435277054, 'reg_alpha': 0.11051649823979912, 'reg_lambda': 1.9856716402598042, 'threshold': 0.6066728609075609, 'adx_th': 16, 'vol_q': 0.5906862999408049}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:31,788] Trial 94 finished with value: 3.4650418816451096 and parameters: {'n_estimators': 321, 'max_depth': 9, 'learning_rate': 0.042957557884482064, 'subsample': 0.8801723218918702, 'colsample_bytree': 0.8294149061691273, 'gamma': 0.2783754643559703, 'reg_alpha': 0.079435172918308, 'reg_lambda': 1.0465974515833636, 'threshold': 0.5919217257141323, 'adx_th': 15, 'vol_q': 0.6219200332720136}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:33,695] Trial 95 finished with value: 2.553528320036841 and parameters: {'n_estimators': 296, 'max_depth': 8, 'learning_rate': 0.0700828451181148, 'subsample': 0.9061848971510588, 'colsample_bytree': 0.8188593038270309, 'gamma': 0.29838361865135515, 'reg_alpha': 0.11309928106515732, 'reg_lambda': 1.9423879388426606, 'threshold': 0.5981528715450651, 'adx_th': 14, 'vol_q': 0.6288631187460121}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:34,555] Trial 96 finished with value: 1.8556159538594752 and parameters: {'n_estimators': 310, 'max_depth': 3, 'learning_rate': 0.05951904415088277, 'subsample': 0.9256826816217535, 'colsample_bytree': 0.7874895086702547, 'gamma': 0.2555242646698235, 'reg_alpha': 0.03382020298025454, 'reg_lambda': 1.998066696670933, 'threshold': 0.6072141602024212, 'adx_th': 15, 'vol_q': 0.616162599986087}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:37,124] Trial 97 finished with value: 2.0302322332665668 and parameters: {'n_estimators': 274, 'max_depth': 9, 'learning_rate': 0.05130759632395325, 'subsample': 0.8627148831484559, 'colsample_bytree': 0.8017982814314097, 'gamma': 0.32074891270394085, 'reg_alpha': 0.0504524114695362, 'reg_lambda': 1.9703069735221603, 'threshold': 0.6004109359309755, 'adx_th': 16, 'vol_q': 0.6047578075250871}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:41,280] Trial 98 finished with value: 2.2197447192450634 and parameters: {'n_estimators': 295, 'max_depth': 9, 'learning_rate': 0.044729212829456494, 'subsample': 0.8842839842256323, 'colsample_bytree': 0.8370335202146176, 'gamma': 0.3116492322014048, 'reg_alpha': 0.10223290715724612, 'reg_lambda': 1.9086489683935994, 'threshold': 0.5841903214903434, 'adx_th': 13, 'vol_q': 0.5679217359647767}. Best is trial 63 with value: 5.072421423887901.
# [I 2026-04-24 20:22:44,098] Trial 99 finished with value: 1.7169436443797732 and parameters: {'n_estimators': 271, 'max_depth': 9, 'learning_rate': 0.023180324918659324, 'subsample': 0.8707674367894652, 'colsample_bytree': 0.729661939807431, 'gamma': 0.2815837617172673, 'reg_alpha': 0.0643197412317785, 'reg_lambda': 1.854709794190526, 'threshold': 0.6181813561206869, 'adx_th': 18, 'vol_q': 0.583560681687978}. Best is trial 63 with value: 5.072421423887901.
# {'n_estimators': 228, 'max_depth': 10, 'learning_rate': 0.05553816864991287, 'subsample': 0.8813729066437143, 'colsample_bytree': 0.7844641899773604, 'gamma': 0.24131935759481857, 'reg_alpha': 0.16744938924176078, 'reg_lambda': 1.9090558784360103, 'threshold': 0.6416710235062494, 'adx_th': 16, 'vol_q': 0.623591023137005}

# %%
print("proba exists:", "proba" in globals())
# Out:
# proba exists: False

# %%
best_params = study.best_params
print(best_params)  # 念のため確認

model_params = {
    k: best_params[k] for k in [
        'n_estimators','max_depth','learning_rate',
        'subsample','colsample_bytree',
        'gamma','reg_alpha','reg_lambda'
    ]
}

strategy_params = {
    "threshold": best_params["threshold"],
    "adx_th": best_params["adx_th"],
    "vol_q": best_params["vol_q"]
}
# Out:
# {'n_estimators': 228, 'max_depth': 10, 'learning_rate': 0.05553816864991287, 'subsample': 0.8813729066437143, 'colsample_bytree': 0.7844641899773604, 'gamma': 0.24131935759481857, 'reg_alpha': 0.16744938924176078, 'reg_lambda': 1.9090558784360103, 'threshold': 0.6416710235062494, 'adx_th': 16, 'vol_q': 0.623591023137005}

# %%
model = XGBClassifier(
    **model_params,
    random_state=42,
    eval_metric='logloss',
    n_jobs=-1
)

# %%
# ======================
# 最終モデル + 最終バックテスト
# ======================

from xgboost import XGBClassifier

# --- Optunaの最適パラメータ取得 ---
best_params = study.best_params.copy()

# thresholdは別で使う
best_threshold = best_params.pop('threshold')

print("Best threshold:", best_threshold)
print("Best model params:", best_params)

# ======================
# モデル再学習（全訓練データ）
# ======================

# SMOTE（訓練データのみ）
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# モデル作成
final_model = XGBClassifier(
    **best_params,
    random_state=42,
    eval_metric='logloss',
    n_jobs=-1
)

# 学習
final_model.fit(X_train_resampled, y_train_resampled)

# ======================
# 予測
# ======================

proba_final = final_model.predict_proba(X_test)[:, 1]

# ======================
# 戦略（最適threshold）
# ======================

strategy_final = (proba_final > best_threshold).astype(int)

# Series化（重要）
signals_final = pd.Series(strategy_final, index=X_test.index)

# ======================
# バックテスト
# ======================

results_final, equity_final = run_backtest(df, X_test, signals_final)

# ======================
# 結果表示
# ======================

print("===== FINAL RESULT =====")
for k, v in results_final.items():
    print(f"{k}: {v}")
# Out:
# Best threshold: 0.6416710235062494
# Best model params: {'n_estimators': 228, 'max_depth': 10, 'learning_rate': 0.05553816864991287, 'subsample': 0.8813729066437143, 'colsample_bytree': 0.7844641899773604, 'gamma': 0.24131935759481857, 'reg_alpha': 0.16744938924176078, 'reg_lambda': 1.9090558784360103, 'adx_th': 16, 'vol_q': 0.623591023137005}
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [20:23:24] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "adx_th", "vol_q" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ===== FINAL RESULT =====
# Final Balance: 110871.08236192743
# Total Return (%): 10.87108236192742
# Total Trades: 13
# Win Rate (%): 46.15384615384615

# %%
import matplotlib.pyplot as plt

plt.plot(equity_final)
plt.title("Final Strategy Equity Curve")
plt.show()

# %%
# ======================
# 時系列CVで最終戦略を検証
# ======================

from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import pandas as pd

tscv = TimeSeriesSplit(n_splits=5)

results_list = []
equity_curves = []

# --- Optunaの最適パラメータ取得 (best_params はグローバルに存在すると仮定) ---
# best_params は既に study.best_params として定義されているはず
# Freshly get best_params from study to avoid prior modifications
best_params_cv = study.best_params.copy()

for fold, (train_idx, test_idx) in enumerate(tscv.split(X)):

    print(f"\n===== Fold {fold+1} ====")

    X_train_cv, X_test_cv = X.iloc[train_idx], X.iloc[test_idx]
    y_train_cv, y_test_cv = y.iloc[train_idx], y.iloc[test_idx]

    # --- SMOTE（訓練データのみ） ---
    smote = SMOTE(random_state=42)
    X_train_res, y_train_res = smote.fit_resample(X_train_cv, y_train_cv)

    # --- モデル（Optunaの最適パラメータ） ---
    # best_params_cvには'threshold', 'adx_th', 'vol_q'が含まれるので、
    # モデルパラメータから除外してXGBClassifierに渡す
    model_params_for_xgb = {k: best_params_cv[k] for k in best_params_cv if k not in [
        'threshold','adx_th','vol_q'
    ]}

    # Initialize model for each fold
    model = XGBClassifier(
        **model_params_for_xgb,
        random_state=42,
        eval_metric='logloss',
        n_jobs=-1
    )

    model.fit(X_train_res, y_train_res)

    # --- 予測 ---
    proba = model.predict_proba(X_test_cv)[:, 1]

    # --- 戦略 ---
    df_slice = df.loc[X_test_cv.index].copy()
    df_slice['proba'] = proba
    # ADXとVolatility_Shortはdf_sliceに存在しない場合があるので、dfから取得
    df_slice['ADX'] = df.loc[X_test_cv.index, 'ADX']
    df_slice['Volatility_Short'] = df.loc[X_test_cv.index, 'Volatility_Short']
    # MACDとSignal_Lineは戦略には直接使用しないが、df_sliceに含める場合はここで追加
    # df_slice['MACD'] = df.loc[X_test_cv.index, 'MACD']
    # df_slice['Signal_Line'] = df.loc[X_test_cv.index, 'Signal_Line']

    vol_threshold = df_slice['Volatility_Short'].quantile(best_params_cv["vol_q"])

    signals = (
        (df_slice['proba'] > best_params_cv["threshold"]) &
        (df_slice['ADX'] > best_params_cv["adx_th"]) &
        (df_slice['Volatility_Short'] > vol_threshold)
    ).astype(int)

    # --- バックテスト ---
    results, equity = run_backtest(df, X_test_cv, signals)

    results_list.append(results)
    equity_curves.append(equity)

    print(results)

# ======================
# 結果まとめ
# ======================

df_results = pd.DataFrame(results_list)

print("\n===== CV SUMMARY ====")
print(df_results.mean())
print("\nSTD:")
print(df_results.std())
# Out:
# ===== Fold 1 ====
# {'Final Balance': np.float64(115255.69144482979), 'Total Return (%)': np.float64(15.25569144482979), 'Total Trades': 10, 'Win Rate (%)': 60.0}
#
# ===== Fold 2 ====
# {'Final Balance': np.float64(101891.43247123114), 'Total Return (%)': np.float64(1.891432471231136), 'Total Trades': 8, 'Win Rate (%)': 50.0}
#
# ===== Fold 3 ====
# {'Final Balance': np.float64(103012.26273614561), 'Total Return (%)': np.float64(3.01226273614561), 'Total Trades': 5, 'Win Rate (%)': 60.0}
#
# ===== Fold 4 ====
# {'Final Balance': np.float64(103148.03980620044), 'Total Return (%)': np.float64(3.148039806200442), 'Total Trades': 7, 'Win Rate (%)': 57.14285714285714}
#
# ===== Fold 5 ====
# {'Final Balance': np.float64(113124.39783235785), 'Total Return (%)': np.float64(13.12439783235786), 'Total Trades': 5, 'Win Rate (%)': 80.0}
#
# ===== CV SUMMARY ====
# Final Balance       107286.364858
# Total Return (%)         7.286365
# Total Trades             7.000000
# Win Rate (%)            61.428571
# dtype: float64
#
# STD:
# Final Balance       6365.763385
# Total Return (%)       6.365763
# Total Trades           2.121320
# Win Rate (%)          11.157500
# dtype: float64

# %%
print('ADX' in df.columns)
print(df.columns)
